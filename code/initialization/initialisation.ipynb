# %% [markdown]
# # Embedding a 2D Circle with t-SNE
# following the paper "Initialization is critical for preserving global data
# structure in both t-SNE and UMAP" by Kobak and Lindermann

# %%
# %matplotlib inline 

import numpy as np
import pylab as plt
import seaborn as sns
sns.set_theme(context='paper', style='ticks', font='Arial')

from openTSNE import TSNE

import openTSNE
print('openTSNE', openTSNE.__version__)
# Out:
# openTSNE 1.0.2

# %% [markdown]
# ## t-SNE on a circle

# %%
# Generate the data

n = 7000
np.random.seed(42)
X = np.random.randn(n,3) / 1000
X[:,0] += np.cos(np.arange(n)*2*np.pi/n)
X[:,1] += np.sin(np.arange(n)*2*np.pi/n)

# %%
# %%time

# BH is faster for this sample size
Z1 = TSNE(n_jobs=-1, n_iter=1000, initialization='random', random_state=42, negative_gradient_method='bh', verbose=True).fit(X)
Z2 = TSNE(n_jobs=-1,n_iter=1000, negative_gradient_method='bh', verbose=True).fit(X)
# Out:
# CPU times: user 8min 57s, sys: 9.04 s, total: 9min 6s
# Wall time: 9min 47s

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(sns.husl_palette(n))

titles = ['Data', 't-SNE, random init', 't-SNE, PCA init']

plt.figure(figsize=(8,2))

for i,Z in enumerate([X,Z1,Z2],1):
    plt.subplot(1,3,i)
    plt.gca().set_aspect('equal', adjustable='datalim')
    plt.scatter(Z[:,0], Z[:,1], s=1, c=np.arange(n), cmap=cmap, 
                edgecolor='none', rasterized=True)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i-1], fontsize=8)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()

plt.show()
# plt.savefig('tsne-circle.png', dpi=300)
# plt.savefig('tsne-umap-circle.pdf', dpi=300)

# %% [markdown]
# ## trying the same on an equilateral triangle

# %%
# Define equilateral triangle vertices
v1 = np.array([0, 0])
v2 = np.array([1, 0])
v3 = np.array([0.5, np.sqrt(3) / 2])

# Parametric representation of the triangle perimeter
t = np.linspace(0, 1, n, endpoint=False)  # Parameter along the perimeter

# Determine which edge each point belongs to
edge = (t * 3).astype(int)  # 3 edges

# Interpolate along edges
X_trig = np.zeros((n, 2))
X_trig[edge == 0] = np.outer(t[edge == 0] * 3, v2 - v1) + v1  # Bottom edge
X_trig[edge == 1] = np.outer((t[edge == 1] - 1/3) * 3, v3 - v2) + v2  # Right edge
X_trig[edge == 2] = np.outer((t[edge == 2] - 2/3) * 3, v1 - v3) + v3  # Left edge

# Add small Gaussian noise
X_trig += np.random.randn(n, 2) / 1000

# %%
# BH is faster for this sample size
Z1_trig = TSNE(n_jobs=-1, initialization='random', random_state=42, negative_gradient_method='bh', verbose=True).fit(X_trig)
Z2_trig = TSNE(n_jobs=-1, random_state=42, negative_gradient_method='bh', verbose=True).fit(X_trig)
Z3_trig = TSNE(n_jobs=-1, random_state=12, negative_gradient_method='bh', verbose=True).fit(X_trig)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, initialization='random', n_jobs=-1,
#      negative_gradient_method='bh', random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 4.75 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.52 seconds
# ===> Running optimization with exaggeration=12.00, lr=583.33 for 250 iterations...
# Iteration   50, KL divergence 3.4867, 50 iterations in 13.8198 sec
# Iteration  100, KL divergence 2.7657, 50 iterations in 9.2859 sec
# Iteration  150, KL divergence 2.3541, 50 iterations in 9.4069 sec
# Iteration  200, KL divergence 2.1641, 50 iterations in 9.4297 sec
# Iteration  250, KL divergence 2.0399, 50 iterations in 8.7993 sec
#    --> Time elapsed: 50.74 seconds
# ===> Running optimization with exaggeration=1.00, lr=7000.00 for 500 iterations...
# Iteration   50, KL divergence 0.7598, 50 iterations in 10.9760 sec
# Iteration  100, KL divergence 0.5403, 50 iterations in 14.1083 sec
# Iteration  150, KL divergence 0.4541, 50 iterations in 10.4587 sec
# Iteration  200, KL divergence 0.4093, 50 iterations in 10.2325 sec
# Iteration  250, KL divergence 0.3823, 50 iterations in 10.2881 sec
# Iteration  300, KL divergence 0.3643, 50 iterations in 10.3000 sec
# Iteration  350, KL divergence 0.3517, 50 iterations in 10.0132 sec
# Iteration  400, KL divergence 0.3421, 50 iterations in 12.0993 sec
# Iteration  450, KL divergence 0.3346, 50 iterations in 11.3374 sec
# Iteration  500, KL divergence 0.3283, 50 iterations in 10.6579 sec
#    --> Time elapsed: 110.47 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, negative_gradient_method='bh',
#      random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 2.94 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.33 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=12.00, lr=583.33 for 250 iterations...
# Iteration   50, KL divergence 2.9869, 50 iterations in 10.4418 sec
# Iteration  100, KL divergence 2.4305, 50 iterations in 13.0021 sec
# Iteration  150, KL divergence 2.1377, 50 iterations in 14.9224 sec
# Iteration  200, KL divergence 1.9763, 50 iterations in 10.8166 sec
# Iteration  250, KL divergence 1.8760, 50 iterations in 9.0060 sec
#    --> Time elapsed: 58.19 seconds
# ===> Running optimization with exaggeration=1.00, lr=7000.00 for 500 iterations...
# Iteration   50, KL divergence 0.7324, 50 iterations in 11.2820 sec
# Iteration  100, KL divergence 0.5130, 50 iterations in 10.8075 sec
# Iteration  150, KL divergence 0.4255, 50 iterations in 10.3932 sec
# Iteration  200, KL divergence 0.3790, 50 iterations in 10.3093 sec
# Iteration  250, KL divergence 0.3507, 50 iterations in 9.8804 sec
# Iteration  300, KL divergence 0.3310, 50 iterations in 11.5563 sec
# Iteration  350, KL divergence 0.3177, 50 iterations in 11.3431 sec
# Iteration  400, KL divergence 0.3090, 50 iterations in 10.3334 sec
# Iteration  450, KL divergence 0.3014, 50 iterations in 10.4724 sec
# Iteration  500, KL divergence 0.2946, 50 iterations in 10.4528 sec
#    --> Time elapsed: 106.83 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, negative_gradient_method='bh',
#      random_state=12, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 2.64 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.32 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=583.33 for 250 iterations...
# Iteration   50, KL divergence 2.9877, 50 iterations in 10.7377 sec
# Iteration  100, KL divergence 2.4247, 50 iterations in 10.5455 sec
# Iteration  150, KL divergence 2.1243, 50 iterations in 12.2185 sec
# Iteration  200, KL divergence 1.9670, 50 iterations in 13.3591 sec
# Iteration  250, KL divergence 1.8699, 50 iterations in 10.8099 sec
#    --> Time elapsed: 57.67 seconds
# ===> Running optimization with exaggeration=1.00, lr=7000.00 for 500 iterations...
# Iteration   50, KL divergence 0.7302, 50 iterations in 10.7018 sec
# Iteration  100, KL divergence 0.5121, 50 iterations in 9.8838 sec
# Iteration  150, KL divergence 0.4244, 50 iterations in 10.1878 sec
# Iteration  200, KL divergence 0.3777, 50 iterations in 11.9495 sec
# Iteration  250, KL divergence 0.3494, 50 iterations in 10.9702 sec
# Iteration  300, KL divergence 0.3306, 50 iterations in 10.1601 sec
# Iteration  350, KL divergence 0.3171, 50 iterations in 10.6461 sec
# Iteration  400, KL divergence 0.3070, 50 iterations in 10.3340 sec
# Iteration  450, KL divergence 0.2990, 50 iterations in 9.5137 sec
# Iteration  500, KL divergence 0.2926, 50 iterations in 12.2206 sec
#    --> Time elapsed: 106.57 seconds

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(sns.husl_palette(n))

titles = ['Data', 't-SNE, random init', 't-SNE, PCA init, seed 42', 't-SNE, PCA init, seed 12']

plt.figure(figsize=(10,2))

for i,Z in enumerate([X_trig, Z1_trig, Z2_trig, Z3_trig],1):
    plt.subplot(1,4,i)
    plt.gca().set_aspect('equal', adjustable='datalim')
    plt.scatter(Z[:,0], Z[:,1], s=1, c=np.arange(n), cmap=cmap, 
                edgecolor='none', rasterized=True)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i-1], fontsize=8)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## t-SNE on a square

# %%
# Define square vertices
v1 = np.array([0, 0])   # Bottom-left
v2 = np.array([1, 0])   # Bottom-right
v3 = np.array([1, 1])   # Top-right
v4 = np.array([0, 1])   # Top-left

# Parametric representation of the square perimeter
t = np.linspace(0, 1, n, endpoint=False)  # Parameter along the perimeter

# Determine which edge each point belongs to
edge = (t * 4).astype(int)  # 4 edges

# Interpolate along edges
X_square = np.zeros((n, 2))
X_square[edge == 0] = np.outer(t[edge == 0] * 4, v2 - v1) + v1  # Bottom edge
X_square[edge == 1] = np.outer((t[edge == 1] - 1/4) * 4, v3 - v2) + v2  # Right edge
X_square[edge == 2] = np.outer((t[edge == 2] - 2/4) * 4, v4 - v3) + v3  # Top edge
X_square[edge == 3] = np.outer((t[edge == 3] - 3/4) * 4, v1 - v4) + v4  # Left edge

# Add small Gaussian noise
X_square += np.random.randn(n, 2) / 1000

# %%
# BH is faster for this sample size
Z0_square = TSNE(n_jobs=-1, initialization='random', random_state=12, negative_gradient_method='bh').fit(X_square)
Z1_square = TSNE(n_jobs=-1, initialization='random', random_state=42, negative_gradient_method='bh').fit(X_square)
Z2_square = TSNE(n_jobs=-1, random_state=42, negative_gradient_method='bh').fit(X_square)
Z3_square = TSNE(n_jobs=-1, random_state=12, negative_gradient_method='bh').fit(X_square)

# %%
titles = ['Data', 't-SNE, random init, seed 12', 't-SNE, random init, seed 42', 't-SNE, PCA init, seed 42', 't-SNE, PCA init, seed 12']

plt.figure(figsize=(10,2))

for i,Z in enumerate([X_square, Z0_square, Z1_square, Z2_square, Z3_square],1):
    plt.subplot(1,5,i)
    plt.gca().set_aspect('equal', adjustable='datalim')
    plt.scatter(Z[:,0], Z[:,1], s=1, c=np.arange(n), cmap=cmap, 
                edgecolor='none', rasterized=True)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i-1], fontsize=8)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## t-SNE on two three circles next to each other

# %%
# Generate the data
n = 2000
np.random.seed(42)
X = np.random.randn(n, 3) / 1000
spacing = 2 

# Generate first circle (centered at origin)
X[:, 0] += np.cos(np.arange(n) * 2 * np.pi / n)
X[:, 1] += np.sin(np.arange(n) * 2 * np.pi / n)

# Second circle: Shift to the right
X2 = X.copy()
X2[:, 0] += 2 * spacing # Move right

# Third circle: Shift up and centered between first two circles
X3 = X.copy()
X3[:, 0] += spacing  # Move slightly to the right
X3[:, 1] += np.sqrt(3) * spacing  # Move up to form an equilateral triangle

# Combine all circles
X_all = np.vstack([X, X2, X3])

# %%
# %%time

# BH is faster for this sample size
Z1_all = TSNE(n_jobs=-1, n_iter=1000, initialization='random', random_state=42, negative_gradient_method='bh', verbose=True).fit(X_all)
Z2_all = TSNE(n_jobs=-1,n_iter=1000, negative_gradient_method='bh', verbose=True).fit(X_all)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, initialization='random', n_iter=1000, n_jobs=-1,
#      negative_gradient_method='bh', random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 3.29 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.27 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 3.4017, 50 iterations in 14.3486 sec
# Iteration  100, KL divergence 2.6452, 50 iterations in 8.4343 sec
# Iteration  150, KL divergence 2.2486, 50 iterations in 8.6094 sec
# Iteration  200, KL divergence 2.0346, 50 iterations in 7.7111 sec
# Iteration  250, KL divergence 1.8992, 50 iterations in 7.2922 sec
#    --> Time elapsed: 46.40 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 1000 iterations...
# Iteration   50, KL divergence 0.6754, 50 iterations in 7.9982 sec
# Iteration  100, KL divergence 0.4763, 50 iterations in 7.6088 sec
# Iteration  150, KL divergence 0.4002, 50 iterations in 7.7656 sec
# Iteration  200, KL divergence 0.3609, 50 iterations in 9.9020 sec
# Iteration  250, KL divergence 0.3373, 50 iterations in 8.6631 sec
# Iteration  300, KL divergence 0.3217, 50 iterations in 8.2065 sec
# Iteration  350, KL divergence 0.3102, 50 iterations in 7.6729 sec
# Iteration  400, KL divergence 0.3014, 50 iterations in 7.3777 sec
# Iteration  450, KL divergence 0.2946, 50 iterations in 7.5282 sec
# Iteration  500, KL divergence 0.2887, 50 iterations in 7.5300 sec
# Iteration  550, KL divergence 0.2841, 50 iterations in 9.2459 sec
# Iteration  600, KL divergence 0.2799, 50 iterations in 9.8375 sec
# Iteration  650, KL divergence 0.2766, 50 iterations in 9.6432 sec
# Iteration  700, KL divergence 0.2735, 50 iterations in 10.2246 sec
# Iteration  750, KL divergence 0.2706, 50 iterations in 11.0819 sec
# Iteration  800, KL divergence 0.2680, 50 iterations in 15.5235 sec
# Iteration  850, KL divergence 0.2657, 50 iterations in 8.6893 sec
# Iteration  900, KL divergence 0.2637, 50 iterations in 8.5434 sec
# Iteration  950, KL divergence 0.2618, 50 iterations in 8.0831 sec
# Iteration 1000, KL divergence 0.2600, 50 iterations in 9.1168 sec
#    --> Time elapsed: 180.25 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=1000, n_jobs=-1,
#      negative_gradient_method='bh', verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 2.24 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.25 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 2.6130, 50 iterations in 8.2794 sec
# Iteration  100, KL divergence 2.2743, 50 iterations in 8.5081 sec
# Iteration  150, KL divergence 2.0030, 50 iterations in 8.7240 sec
# Iteration  200, KL divergence 1.8628, 50 iterations in 7.5771 sec
# Iteration  250, KL divergence 1.7760, 50 iterations in 8.0133 sec
#    --> Time elapsed: 41.10 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 1000 iterations...
# Iteration   50, KL divergence 0.6752, 50 iterations in 10.3884 sec
# Iteration  100, KL divergence 0.4721, 50 iterations in 15.1511 sec
# Iteration  150, KL divergence 0.3940, 50 iterations in 11.0724 sec
# Iteration  200, KL divergence 0.3529, 50 iterations in 9.0598 sec
# Iteration  250, KL divergence 0.3273, 50 iterations in 8.6484 sec
# Iteration  300, KL divergence 0.3101, 50 iterations in 8.3249 sec
# Iteration  350, KL divergence 0.2975, 50 iterations in 8.2747 sec
# Iteration  400, KL divergence 0.2879, 50 iterations in 7.9924 sec
# Iteration  450, KL divergence 0.2805, 50 iterations in 8.2147 sec
# Iteration  500, KL divergence 0.2742, 50 iterations in 9.0909 sec
# Iteration  550, KL divergence 0.2695, 50 iterations in 8.3022 sec
# Iteration  600, KL divergence 0.2652, 50 iterations in 8.2286 sec
# Iteration  650, KL divergence 0.2615, 50 iterations in 7.9209 sec
# Iteration  700, KL divergence 0.2582, 50 iterations in 8.3234 sec
# Iteration  750, KL divergence 0.2553, 50 iterations in 7.7502 sec
# Iteration  800, KL divergence 0.2529, 50 iterations in 8.2707 sec
# Iteration  850, KL divergence 0.2507, 50 iterations in 7.4815 sec
# Iteration  900, KL divergence 0.2486, 50 iterations in 8.7671 sec
# Iteration  950, KL divergence 0.2467, 50 iterations in 7.8065 sec
# Iteration 1000, KL divergence 0.2451, 50 iterations in 10.2779 sec
#    --> Time elapsed: 179.35 seconds
# CPU times: user 6min 58s, sys: 5.74 s, total: 7min 3s
# Wall time: 7min 33s

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(sns.husl_palette(n))

titles = ['Data', 't-SNE, random init', 't-SNE, PCA init']

plt.figure(figsize=(8,2))

for i,Z in enumerate([X_all,Z1_all,Z2_all],1):
    plt.subplot(1,3,i)
    plt.gca().set_aspect('equal', adjustable='datalim')
    plt.scatter(Z[:,0], Z[:,1], s=1, c=np.arange(6000), cmap=cmap, 
                edgecolor='none', rasterized=True)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i-1], fontsize=8)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## t-SNE with spectral clustering initialization

# %%
# %%time

# BH is faster for this sample size
Z3_spectral = TSNE(n_jobs=-1,n_iter=1000, negative_gradient_method='bh', verbose=True).fit(X_all, initialization="spectral")
Z1_rand = TSNE(n_jobs=-1, n_iter=1000, initialization='random', random_state=42, negative_gradient_method='bh', verbose=True).fit(X_all)
Z2_pca = TSNE(n_jobs=-1,n_iter=1000, negative_gradient_method='bh', verbose=True).fit(X_all)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=1000, n_jobs=-1,
#      negative_gradient_method='bh', verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 3.20 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.30 seconds
# ===> Calculating spectral initialization...
#    --> Time elapsed: 0.27 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 2.6026, 50 iterations in 17.9823 sec
# Iteration  100, KL divergence 2.4235, 50 iterations in 16.1724 sec
# Iteration  150, KL divergence 2.2443, 50 iterations in 17.4655 sec
# Iteration  200, KL divergence 2.1568, 50 iterations in 14.8094 sec
# Iteration  250, KL divergence 2.1073, 50 iterations in 10.4321 sec
#    --> Time elapsed: 76.87 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 1000 iterations...
# Iteration   50, KL divergence 0.7200, 50 iterations in 18.1427 sec
# Iteration  100, KL divergence 0.5262, 50 iterations in 10.9107 sec
# Iteration  150, KL divergence 0.4555, 50 iterations in 11.8572 sec
# Iteration  200, KL divergence 0.4191, 50 iterations in 10.0146 sec
# Iteration  250, KL divergence 0.3965, 50 iterations in 10.2375 sec
# Iteration  300, KL divergence 0.3802, 50 iterations in 9.9291 sec
# Iteration  350, KL divergence 0.3696, 50 iterations in 9.5317 sec
# Iteration  400, KL divergence 0.3614, 50 iterations in 10.2433 sec
# Iteration  450, KL divergence 0.3552, 50 iterations in 10.9838 sec
# Iteration  500, KL divergence 0.3501, 50 iterations in 9.6575 sec
# Iteration  550, KL divergence 0.3457, 50 iterations in 10.4424 sec
# Iteration  600, KL divergence 0.3422, 50 iterations in 9.8776 sec
# Iteration  650, KL divergence 0.3390, 50 iterations in 9.2923 sec
# Iteration  700, KL divergence 0.3362, 50 iterations in 9.9350 sec
# Iteration  750, KL divergence 0.3335, 50 iterations in 11.7607 sec
# Iteration  800, KL divergence 0.3315, 50 iterations in 10.3757 sec
# Iteration  850, KL divergence 0.3295, 50 iterations in 10.9788 sec
# Iteration  900, KL divergence 0.3276, 50 iterations in 11.1726 sec
# Iteration  950, KL divergence 0.3258, 50 iterations in 16.0976 sec
# Iteration 1000, KL divergence 0.3243, 50 iterations in 11.9042 sec
#    --> Time elapsed: 223.35 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, initialization='random', n_iter=1000, n_jobs=-1,
#      negative_gradient_method='bh', random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 2.94 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.62 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 3.4017, 50 iterations in 17.0756 sec
# Iteration  100, KL divergence 2.6448, 50 iterations in 13.8188 sec
# Iteration  150, KL divergence 2.2501, 50 iterations in 11.9509 sec
# Iteration  200, KL divergence 2.0420, 50 iterations in 11.4382 sec
# Iteration  250, KL divergence 1.9007, 50 iterations in 10.7641 sec
#    --> Time elapsed: 65.05 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 1000 iterations...
# Iteration   50, KL divergence 0.6756, 50 iterations in 18.6272 sec
# Iteration  100, KL divergence 0.4758, 50 iterations in 12.7778 sec
# Iteration  150, KL divergence 0.4003, 50 iterations in 8.8280 sec
# Iteration  200, KL divergence 0.3616, 50 iterations in 9.4728 sec
# Iteration  250, KL divergence 0.3381, 50 iterations in 8.3852 sec
# Iteration  300, KL divergence 0.3220, 50 iterations in 9.3946 sec
# Iteration  350, KL divergence 0.3104, 50 iterations in 8.1294 sec
# Iteration  400, KL divergence 0.3016, 50 iterations in 8.4538 sec
# Iteration  450, KL divergence 0.2949, 50 iterations in 9.7339 sec
# Iteration  500, KL divergence 0.2895, 50 iterations in 8.3783 sec
# Iteration  550, KL divergence 0.2845, 50 iterations in 8.0607 sec
# Iteration  600, KL divergence 0.2804, 50 iterations in 7.7493 sec
# Iteration  650, KL divergence 0.2769, 50 iterations in 7.9457 sec
# Iteration  700, KL divergence 0.2738, 50 iterations in 7.8217 sec
# Iteration  750, KL divergence 0.2709, 50 iterations in 7.8440 sec
# Iteration  800, KL divergence 0.2685, 50 iterations in 7.5507 sec
# Iteration  850, KL divergence 0.2663, 50 iterations in 8.0562 sec
# Iteration  900, KL divergence 0.2642, 50 iterations in 7.5253 sec
# Iteration  950, KL divergence 0.2622, 50 iterations in 8.2628 sec
# Iteration 1000, KL divergence 0.2603, 50 iterations in 7.5366 sec
#    --> Time elapsed: 180.54 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=1000, n_jobs=-1,
#      negative_gradient_method='bh', verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 2.35 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.24 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 2.5909, 50 iterations in 7.4688 sec
# Iteration  100, KL divergence 2.2660, 50 iterations in 7.4310 sec
# Iteration  150, KL divergence 1.9991, 50 iterations in 7.0978 sec
# Iteration  200, KL divergence 1.8605, 50 iterations in 7.6123 sec
# Iteration  250, KL divergence 1.7733, 50 iterations in 11.7745 sec
#    --> Time elapsed: 41.39 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 1000 iterations...
# Iteration   50, KL divergence 0.6753, 50 iterations in 13.9541 sec
# Iteration  100, KL divergence 0.4716, 50 iterations in 9.6712 sec
# Iteration  150, KL divergence 0.3938, 50 iterations in 7.3279 sec
# Iteration  200, KL divergence 0.3524, 50 iterations in 7.6113 sec
# Iteration  250, KL divergence 0.3268, 50 iterations in 6.9834 sec
# Iteration  300, KL divergence 0.3096, 50 iterations in 7.1827 sec
# Iteration  350, KL divergence 0.2976, 50 iterations in 8.9539 sec
# Iteration  400, KL divergence 0.2883, 50 iterations in 9.5841 sec
# Iteration  450, KL divergence 0.2809, 50 iterations in 8.0949 sec
# Iteration  500, KL divergence 0.2747, 50 iterations in 7.5904 sec
# Iteration  550, KL divergence 0.2697, 50 iterations in 7.8392 sec
# Iteration  600, KL divergence 0.2655, 50 iterations in 7.6971 sec
# Iteration  650, KL divergence 0.2620, 50 iterations in 7.8731 sec
# Iteration  700, KL divergence 0.2588, 50 iterations in 7.5752 sec
# Iteration  750, KL divergence 0.2560, 50 iterations in 9.5303 sec
# Iteration  800, KL divergence 0.2532, 50 iterations in 8.1549 sec
# Iteration  850, KL divergence 0.2509, 50 iterations in 8.1280 sec
# Iteration  900, KL divergence 0.2487, 50 iterations in 7.8252 sec
# Iteration  950, KL divergence 0.2467, 50 iterations in 7.7185 sec
# Iteration 1000, KL divergence 0.2450, 50 iterations in 8.0344 sec
#    --> Time elapsed: 167.33 seconds
# CPU times: user 11min 15s, sys: 11.2 s, total: 11min 26s
# Wall time: 12min 45s

# %%
from matplotlib.colors import ListedColormap
cmap = ListedColormap(sns.husl_palette(n))

titles = ['Data', 't-SNE, random init', 't-SNE, PCA init', 't-SNE, spectral init']

plt.figure(figsize=(8,2))

for i,Z in enumerate([X_all,Z1_rand,Z2_pca, Z3_spectral],1):
    plt.subplot(1,4,i)
    plt.gca().set_aspect('equal', adjustable='datalim')
    plt.scatter(Z[:,0], Z[:,1], s=1, c=np.arange(6000), cmap=cmap, 
                edgecolor='none', rasterized=True)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i-1], fontsize=8)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()

plt.show()

# %% [markdown]
# ### when do we get these weird lines?

# %%
# Generate the data with fewer points
n = 700
np.random.seed(42)
X = np.random.randn(n,3) / 1000
X[:,0] += np.cos(np.arange(n)*2*np.pi/n)
X[:,1] += np.sin(np.arange(n)*2*np.pi/n)

# %%
# %%time

# BH is faster for this sample size
Z1 = TSNE(perplexity=10, n_jobs=-1, n_iter=50, random_state=42, verbose=True).fit(X)
Z2 = TSNE(perplexity=40, n_jobs=-1,n_iter=50, verbose=True).fit(X)
Z3 = TSNE(perplexity=60, n_jobs=-1,n_iter=50, verbose=True).fit(X)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=50, n_jobs=-1, perplexity=10,
#      random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 30 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.06 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=58.33 for 250 iterations...
# Iteration   50, KL divergence 2.0520, 50 iterations in 1.3467 sec
# Iteration  100, KL divergence 1.8535, 50 iterations in 1.7503 sec
# Iteration  150, KL divergence 1.6655, 50 iterations in 0.8227 sec
# Iteration  200, KL divergence 1.5708, 50 iterations in 0.6660 sec
# Iteration  250, KL divergence 1.5163, 50 iterations in 0.6623 sec
#    --> Time elapsed: 5.25 seconds
# ===> Running optimization with exaggeration=1.00, lr=700.00 for 50 iterations...
# Iteration   50, KL divergence 0.4650, 50 iterations in 0.7664 sec
#    --> Time elapsed: 0.77 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=50, n_jobs=-1, perplexity=40, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 120 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=58.33 for 250 iterations...
# Iteration   50, KL divergence 1.1041, 50 iterations in 0.7086 sec
# Iteration  100, KL divergence 1.2912, 50 iterations in 0.6861 sec
# Iteration  150, KL divergence 1.3175, 50 iterations in 0.6926 sec
# Iteration  200, KL divergence 1.3174, 50 iterations in 0.6870 sec
# Iteration  250, KL divergence 1.3174, 50 iterations in 0.6857 sec
#    --> Time elapsed: 3.46 seconds
# ===> Running optimization with exaggeration=1.00, lr=700.00 for 50 iterations...
# Iteration   50, KL divergence 0.1985, 50 iterations in 0.7286 sec
#    --> Time elapsed: 0.73 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=50, n_jobs=-1, perplexity=60, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 180 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.06 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=58.33 for 250 iterations...
# Iteration   50, KL divergence 1.1914, 50 iterations in 0.7288 sec
# Iteration  100, KL divergence 1.3088, 50 iterations in 0.7037 sec
# Iteration  150, KL divergence 1.3081, 50 iterations in 0.7033 sec
# Iteration  200, KL divergence 1.3081, 50 iterations in 0.6936 sec
# Iteration  250, KL divergence 1.3081, 50 iterations in 0.7071 sec
#    --> Time elapsed: 3.54 seconds
# ===> Running optimization with exaggeration=1.00, lr=700.00 for 50 iterations...
# Iteration   50, KL divergence 0.1772, 50 iterations in 0.7020 sec
#    --> Time elapsed: 0.70 seconds
# CPU times: user 12.3 s, sys: 195 ms, total: 12.5 s
# Wall time: 14.8 s

# %%
Z4 = TSNE(perplexity=100, n_jobs=-1,n_iter=50, verbose=True).fit(X)
Z5 = TSNE(perplexity=200, n_jobs=-1,n_iter=50, verbose=True).fit(X)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=50, n_jobs=-1, perplexity=100, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 300 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.08 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.21 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=58.33 for 250 iterations...
# Iteration   50, KL divergence 1.3572, 50 iterations in 1.3716 sec
# Iteration  100, KL divergence 1.3013, 50 iterations in 1.8786 sec
# Iteration  150, KL divergence 1.3016, 50 iterations in 0.9441 sec
# Iteration  200, KL divergence 1.3016, 50 iterations in 0.8481 sec
# Iteration  250, KL divergence 1.3016, 50 iterations in 1.8720 sec
#    --> Time elapsed: 6.92 seconds
# ===> Running optimization with exaggeration=1.00, lr=700.00 for 50 iterations...
# Iteration   50, KL divergence 0.1710, 50 iterations in 1.8082 sec
#    --> Time elapsed: 1.81 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=50, n_jobs=-1, perplexity=200, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 600 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.08 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.20 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=58.33 for 250 iterations...
# Iteration   50, KL divergence 1.0991, 50 iterations in 1.0288 sec
# Iteration  100, KL divergence 1.1016, 50 iterations in 0.8428 sec
# Iteration  150, KL divergence 1.1405, 50 iterations in 0.8117 sec
# Iteration  200, KL divergence 1.1514, 50 iterations in 0.6646 sec
# Iteration  250, KL divergence 1.1473, 50 iterations in 0.6655 sec
#    --> Time elapsed: 4.01 seconds
# ===> Running optimization with exaggeration=1.00, lr=700.00 for 50 iterations...
# Iteration   50, KL divergence 0.1681, 50 iterations in 0.9381 sec
#    --> Time elapsed: 0.94 seconds

# %%
Z6 = TSNE(perplexity=300, n_jobs=-1,n_iter=50, verbose=True).fit(X)
# Out:
# Perplexity value 300 is too high. Using perplexity 233.00 instead
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_iter=50, n_jobs=-1, perplexity=300, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 699 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.14 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.29 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=58.33 for 250 iterations...
# Iteration   50, KL divergence 0.0090, 50 iterations in 1.2068 sec
# Iteration  100, KL divergence 1.1000, 50 iterations in 0.7663 sec
# Iteration  150, KL divergence 1.1000, 50 iterations in 0.5443 sec
# Iteration  200, KL divergence 1.1000, 50 iterations in 0.5200 sec
# Iteration  250, KL divergence 1.1000, 50 iterations in 0.7514 sec
#    --> Time elapsed: 3.80 seconds
# ===> Running optimization with exaggeration=1.00, lr=700.00 for 50 iterations...
# Iteration   50, KL divergence 0.2296, 50 iterations in 1.6961 sec
#    --> Time elapsed: 1.70 seconds

# %%
cmap = ListedColormap(sns.husl_palette(n))

titles = ['Data', 't-SNE, perp 10', 't-SNE, perp 40', 't-SNE, perp 60', 't-SNE, perp 100', 't-SNE, perp 200', 't-SNE, perp 300']

plt.figure(figsize=(8,2))

for i,Z in enumerate([X,Z1,Z2,Z3,Z4,Z5,Z6],1):
    plt.subplot(1,7,i)
    plt.gca().set_aspect('equal', adjustable='datalim')
    plt.scatter(Z[:,0], Z[:,1], s=1, c=np.arange(n), cmap=cmap, 
                edgecolor='none', rasterized=True)
    plt.xticks([])
    plt.yticks([])
    plt.title(titles[i-1], fontsize=8)
    
sns.despine(left=True, bottom=True)
plt.tight_layout()

plt.show()
