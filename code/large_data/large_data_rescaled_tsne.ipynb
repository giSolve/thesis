# %% [markdown]
# ## Large Data Limits paper
# This is just a rough first version, not entirely true to what it should be.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from openTSNE import TSNE

# %% [markdown]
# ### outdated first attempt

# %%
def run_rescaled_tsne(data, kappa=30, alpha=0.1):
    """
    Run t-SNE with a rescaled perplexity and exaggeration factor.

    Parameters:
      - data: ndarray of shape (n_samples, n_features)
      - kappa: base constant (effective number of neighbors)
      - alpha: exponent to allow perplexity to grow as n^alpha
      
    Returns:
      - embedding: 2D embedding from t-SNE.
    """
    n, d = data.shape
    # Note: b needs to be larger than 1/d and smaller than 1 
    b = 0.12
    h_n = n ** (-b)
    # Perplexity should be chosen to scale slowly with n.
    scaled_perplexity = kappa * (n ** alpha)
    # Early exaggeration factor: rescale the attractive term by 1/h_n^2.
    exaggeration = 1 / (h_n ** 2)
    
    print(f"n = {n}, d = {d}, b={b}")
    print(f"Computed h_n = {h_n:.4f}")
    print(f"Using perplexity = {scaled_perplexity:.2f} (base κ = {kappa}, exponent α = {alpha})")
    print(f"Using early exaggeration = {exaggeration:.2f}")

    tsne = TSNE(
        perplexity=scaled_perplexity,
        early_exaggeration_iter=250,
        exaggeration=exaggeration,
        initialization="pca",
        n_jobs=-1,
        random_state=42,
    )
    embedding = tsne.fit(data)
    return embedding

# %%
def create_synthetic_data(n_points=10000, n_features=50, n_clusters=5, cluster_std=1.0):
    """
    Generate synthetic data as a mixture of Gaussians.
    """
    np.random.seed(42)
    data = []
    labels = []
    centers = np.random.randn(n_clusters, n_features) * 0.7
    points_per_cluster = n_points // n_clusters
    for i in range(n_clusters):
        points = centers[i] + cluster_std * np.random.randn(points_per_cluster, n_features)
        data.append(points)
        labels.append(np.full(points.shape[0], i))
    data = np.vstack(data)
    labels = np.concatenate(labels)

    indices = np.random.permutation(n_points)
    return data[indices], labels[indices]

# %%
def run_standard_tsne(data, perplexity=30, exaggeration=12):
    """
    Run standard t-SNE with fixed perplexity and exaggeration.
    """
    tsne = TSNE(
        perplexity=perplexity,
        early_exaggeration_iter=250,
        exaggeration=exaggeration,
        initialization="pca",
        n_jobs=4,
        random_state=42,
    )
    return tsne.fit(data)

# %%
data_all, labels_all = create_synthetic_data(n_points=1000000, n_features=50, n_clusters=5)
def comp_rescaled_tsne_on_sizes(data_sizes): 
    for n_fixed in data_sizes: 

        sampled_indices = np.random.choice(len(data_all), size=n_fixed, replace=False)

        # Select the random subset of data and labels
        data_subset = data_all[sampled_indices]
        labels_subset = labels_all[sampled_indices]

        # Standard t-SNE (with constant perplexity and exaggeration)
        emb_standard = run_standard_tsne(data_subset, perplexity=30, exaggeration=12)

        # Rescaled t-SNE (per our new model)
        emb_rescaled = run_rescaled_tsne(data_subset, kappa=30, alpha=0.05)

        # cmap = plt.get_cmap("Set1")

        # Plot side-by-side
        plt.figure(figsize=(12, 5))
        plt.subplot(1, 2, 1)
        plt.scatter(emb_standard[:, 0], emb_standard[:, 1], c=labels_subset[:n_fixed], cmap="Set1", s=5)
        plt.title(f"Standard t-SNE, {n_fixed} points")
    
        plt.subplot(1, 2, 2)
        plt.scatter(emb_rescaled[:, 0], emb_rescaled[:, 1], c=labels_subset[:n_fixed], cmap="Set1", s=5)
        plt.title(f"Rescaled t-SNE, {n_fixed} points")
    
        plt.tight_layout()
        plt.show()

# %%
comp_rescaled_tsne_on_sizes([100, 500])
# Out:
# Perplexity value 37 is too high. Using perplexity 33.00 instead
# n = 100, d = 50, b=0.12
# Computed h_n = 0.5754
# Using perplexity = 37.77 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 3.02
# n = 500, d = 50, b=0.12
# Computed h_n = 0.4744
# Using perplexity = 40.93 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 4.44

# %%
comp_rescaled_tsne_on_sizes([100, 500, 1000, 10000, 100000, 1000000])
# Out:
# Perplexity value 37 is too high. Using perplexity 33.00 instead
# n = 100, d = 50, b=0.12
# Computed h_n = 0.5754
# Using perplexity = 37.77 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 3.02
# n = 500, d = 50, b=0.12
# Computed h_n = 0.4744
# Using perplexity = 40.93 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 4.44
# n = 1000, d = 50, b=0.12
# Computed h_n = 0.4365
# Using perplexity = 42.38 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 5.25
# n = 10000, d = 50, b=0.12
# Computed h_n = 0.3311
# Using perplexity = 47.55 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 9.12
# n = 100000, d = 50, b=0.12
# Computed h_n = 0.2512
# Using perplexity = 53.35 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 15.85
# n = 1000000, d = 50, b=0.12
# Computed h_n = 0.1905
# Using perplexity = 59.86 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 27.54

# %% [markdown]
# ## Current attempt

# %% [markdown]
# ### Helper Functions

# %%
def run_rescaled_tsne_improved(data, kappa=30, alpha=0.1, b=0.15):
    """
    Run t-SNE with a rescaled perplexity and exaggeration factor.

    Parameters:
      - data: ndarray of shape (n_samples, n_features)
      - kappa: base constant (effective number of neighbors)
      - alpha: exponent to allow perplexity to grow as n^alpha
      
    Returns:
      - embedding: 2D embedding from t-SNE.
    """
    n, d = data.shape
    # Note: b needs to be larger than 1/d and smaller than 1 
    h_n = n ** (-b)
    # Perplexity should be chosen to scale slowly with n.
    scaled_perplexity = kappa * (n ** alpha)
    # Early exaggeration factor: rescale the attractive term by 1/h_n^2.
    exaggeration = 1 / (h_n ** 2)
    
    print(f"n = {n}, d = {d}, b={b}")
    print(f"Computed h_n = {h_n:.4f}")
    print(f"Using perplexity = {scaled_perplexity:.2f} (base κ = {kappa}, exponent α = {alpha})")
    print(f"Using early exaggeration = {exaggeration:.2f}")

    # keep on EE for the entirety of the optimization  
    tsne = TSNE(
        perplexity=scaled_perplexity,
        early_exaggeration=exaggeration,
        exaggeration=exaggeration, 
        n_jobs=-1,
        random_state=42,
        verbose=True
    )
    embedding = tsne.fit(data)
    return embedding

# %%
def run_standard_tsne_improved(data):
    """
    Run standard t-SNE with fixed perplexity and exaggeration.
    """
    tsne = TSNE(n_jobs=-1, random_state=42, verbose=True
    )
    return tsne.fit(data)

# %%
def sample_gaussian_mixture(n_samples: int, dim: int, n_components: int = 5, spread: float = 5.0):
    """
    Generates samples from a Gaussian Mixture Model with equidistant Gaussian components in high dimensions.

    Parameters:
    - n_samples (int): Total number of samples to generate.
    - dim (int): Dimensionality of the data.
    - n_components (int): Number of Gaussian components (default: 5).
    - spread (float): Controls how far apart the Gaussian centers are (default: 5.0).

    Returns:
    - X (numpy.ndarray): Sampled data of shape (n_samples, dim).
    - labels (numpy.ndarray): Cluster labels for each sample.
    """
    np.random.seed(42)

    # Generate random Gaussian centers in high-dimensional space
    means = np.random.randn(n_components, dim) * spread  # Spread them apart

    # Covariance matrices (identity matrices for simplicity)
    covariances = [np.eye(dim) for _ in range(n_components)]

    # Equal mixing probabilities (each Gaussian has 1/n_components probability)
    component_choices = np.random.choice(n_components, size=n_samples, p=np.ones(n_components) / n_components)

    # Sample from the selected Gaussians
    X = np.array([np.random.multivariate_normal(means[comp], covariances[comp]) for comp in component_choices])

    return X, component_choices  # Return data and the labels indicating which Gaussian each point came from

# %%
def compare_improved(data_sizes, b=0.15, dim=50, n_components=5):
    """
    Generates and compares standard vs. rescaled t-SNE embeddings for different sample sizes.

    Parameters:
    - data_sizes (list): List of sample sizes to generate and compare.
    - dim (int): Dimensionality of the generated data (default: 50).
    - n_components (int): Number of Gaussian components in the mixture (default: 5).
    """
    num_rows = len(data_sizes)  # Number of rows in the plot
    fig, axes = plt.subplots(num_rows, 2, figsize=(10, 5 * num_rows))  # Adjust figure size dynamically
    fig.suptitle("Comparison of Standard vs. Rescaled t-SNE for Different Sample Sizes", fontsize=12, y=1.02)

    for i, n_fixed in enumerate(data_sizes):
        # Sample new data instead of selecting a subset
        data_sample, labels = sample_gaussian_mixture(n_samples=n_fixed, dim=dim, n_components=n_components)

        # Compute embeddings
        emb_standard = run_standard_tsne_improved(data_sample)
        emb_rescaled = run_rescaled_tsne_improved(data_sample, kappa=30, alpha=0.05, b=b)

        # Plot standard t-SNE
        axes[i, 0].scatter(emb_standard[:, 0], emb_standard[:, 1], c=labels, cmap="Set1", s=5)
        axes[i, 0].set_title(f"Standard t-SNE ({n_fixed} points)")

        # Plot rescaled t-SNE
        axes[i, 1].scatter(emb_rescaled[:, 0], emb_rescaled[:, 1], c=labels, cmap="Set1", s=5)
        axes[i, 1].set_title(f"Rescaled t-SNE ({n_fixed} points)")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### running experiments

# %%
compare_improved([100, 500, 1000, 10000, 100000], b=0.15)
compare_improved([100, 500, 1000, 10000, 100000], b=0.05)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=8.33 for 250 iterations...
# Iteration   50, KL divergence 1.0155, 50 iterations in 0.0813 sec
# Iteration  100, KL divergence 1.0673, 50 iterations in 0.0880 sec
# Iteration  150, KL divergence 0.9953, 50 iterations in 0.0818 sec
# Iteration  200, KL divergence 1.0388, 50 iterations in 0.0531 sec
# Iteration  250, KL divergence 1.0292, 50 iterations in 0.0523 sec
#    --> Time elapsed: 0.36 seconds
# ===> Running optimization with exaggeration=1.00, lr=100.00 for 500 iterations...
# Iteration   50, KL divergence 0.0509, 50 iterations in 0.0759 sec
# Iteration  100, KL divergence 0.0088, 50 iterations in 0.1028 sec
# Iteration  150, KL divergence 0.0068, 50 iterations in 0.0888 sec
# Iteration  200, KL divergence 0.0067, 50 iterations in 0.0786 sec
# Iteration  250, KL divergence 0.0067, 50 iterations in 0.0722 sec
# Iteration  300, KL divergence 0.0067, 50 iterations in 0.0648 sec
# Iteration  350, KL divergence 0.0068, 50 iterations in 0.0623 sec
# Iteration  400, KL divergence 0.0068, 50 iterations in 0.0667 sec
# Perplexity value 37 is too high. Using perplexity 33.00 instead
# Iteration  450, KL divergence 0.0068, 50 iterations in 0.0952 sec
# Iteration  500, KL divergence 0.0068, 50 iterations in 0.1741 sec
#    --> Time elapsed: 0.88 seconds
# n = 100, d = 50, b=0.15
# Computed h_n = 0.5012
# Using perplexity = 37.77 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 3.98
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=3.981071705534973, exaggeration=3.981071705534973,
#      n_jobs=-1, perplexity=37.76776235382502, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 99 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=3.98, lr=25.12 for 250 iterations...
# Iteration   50, KL divergence 0.3647, 50 iterations in 0.1631 sec
# Iteration  100, KL divergence 0.3207, 50 iterations in 0.1466 sec
# Iteration  150, KL divergence 0.3205, 50 iterations in 0.1172 sec
# Iteration  200, KL divergence 0.3206, 50 iterations in 0.1777 sec
# Iteration  250, KL divergence 0.3206, 50 iterations in 0.1135 sec
#    --> Time elapsed: 0.72 seconds
# ===> Running optimization with exaggeration=3.98, lr=25.12 for 500 iterations...
# Iteration   50, KL divergence 0.3206, 50 iterations in 0.2172 sec
# Iteration  100, KL divergence 0.3206, 50 iterations in 0.1445 sec
# Iteration  150, KL divergence 0.3206, 50 iterations in 0.2758 sec
# Iteration  200, KL divergence 0.3206, 50 iterations in 0.1683 sec
# Iteration  250, KL divergence 0.3206, 50 iterations in 0.1650 sec
# Iteration  300, KL divergence 0.3206, 50 iterations in 0.1543 sec
# Iteration  350, KL divergence 0.3206, 50 iterations in 0.1813 sec
# Iteration  400, KL divergence 0.3206, 50 iterations in 0.1630 sec
# Iteration  450, KL divergence 0.3206, 50 iterations in 0.1681 sec
# Iteration  500, KL divergence 0.3206, 50 iterations in 0.2454 sec
#    --> Time elapsed: 1.89 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=41.67 for 250 iterations...
# Iteration   50, KL divergence 1.1987, 50 iterations in 1.4343 sec
# Iteration  100, KL divergence 1.1539, 50 iterations in 1.0104 sec
# Iteration  150, KL divergence 1.1276, 50 iterations in 1.2440 sec
# Iteration  200, KL divergence 1.1134, 50 iterations in 0.6974 sec
# Iteration  250, KL divergence 1.1025, 50 iterations in 0.6716 sec
#    --> Time elapsed: 5.06 seconds
# ===> Running optimization with exaggeration=1.00, lr=500.00 for 500 iterations...
# Iteration   50, KL divergence 0.8558, 50 iterations in 0.7547 sec
# Iteration  100, KL divergence 0.8163, 50 iterations in 0.7642 sec
# Iteration  150, KL divergence 0.8024, 50 iterations in 0.6125 sec
# Iteration  200, KL divergence 0.7957, 50 iterations in 0.6512 sec
# Iteration  250, KL divergence 0.7909, 50 iterations in 0.6178 sec
# Iteration  300, KL divergence 0.7878, 50 iterations in 0.5698 sec
# Iteration  350, KL divergence 0.7859, 50 iterations in 0.6271 sec
# Iteration  400, KL divergence 0.7840, 50 iterations in 0.5618 sec
# Iteration  450, KL divergence 0.7831, 50 iterations in 0.5597 sec
# Iteration  500, KL divergence 0.7820, 50 iterations in 0.6086 sec
#    --> Time elapsed: 6.33 seconds
# n = 500, d = 50, b=0.15
# Computed h_n = 0.3937
# Using perplexity = 40.93 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 6.45
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=6.4519501214821595, exaggeration=6.4519501214821595,
#      n_jobs=-1, perplexity=40.93263990964255, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 122 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=6.45, lr=77.50 for 250 iterations...
# Iteration   50, KL divergence 0.8565, 50 iterations in 0.8318 sec
# Iteration  100, KL divergence 0.8392, 50 iterations in 0.7235 sec
# Iteration  150, KL divergence 0.8242, 50 iterations in 0.6661 sec
# Iteration  200, KL divergence 0.8156, 50 iterations in 0.6403 sec
# Iteration  250, KL divergence 0.8099, 50 iterations in 0.6728 sec
#    --> Time elapsed: 3.54 seconds
# ===> Running optimization with exaggeration=6.45, lr=77.50 for 500 iterations...
# Iteration   50, KL divergence 0.8058, 50 iterations in 0.6655 sec
# Iteration  100, KL divergence 0.8027, 50 iterations in 0.6564 sec
# Iteration  150, KL divergence 0.8002, 50 iterations in 0.6406 sec
# Iteration  200, KL divergence 0.7982, 50 iterations in 0.6666 sec
# Iteration  250, KL divergence 0.7964, 50 iterations in 0.6623 sec
# Iteration  300, KL divergence 0.7948, 50 iterations in 0.6144 sec
# Iteration  350, KL divergence 0.7937, 50 iterations in 0.6824 sec
# Iteration  400, KL divergence 0.7925, 50 iterations in 0.6993 sec
# Iteration  450, KL divergence 0.7915, 50 iterations in 0.7217 sec
# Iteration  500, KL divergence 0.7906, 50 iterations in 0.6398 sec
#    --> Time elapsed: 6.65 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.23 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=83.33 for 250 iterations...
# Iteration   50, KL divergence 1.8391, 50 iterations in 1.3849 sec
# Iteration  100, KL divergence 1.7905, 50 iterations in 1.7349 sec
# Iteration  150, KL divergence 1.7633, 50 iterations in 1.5586 sec
# Iteration  200, KL divergence 1.7500, 50 iterations in 1.6576 sec
# Iteration  250, KL divergence 1.7404, 50 iterations in 1.7974 sec
#    --> Time elapsed: 8.13 seconds
# ===> Running optimization with exaggeration=1.00, lr=1000.00 for 500 iterations...
# Iteration   50, KL divergence 1.4178, 50 iterations in 1.2979 sec
# Iteration  100, KL divergence 1.3624, 50 iterations in 1.4851 sec
# Iteration  150, KL divergence 1.3404, 50 iterations in 1.5476 sec
# Iteration  200, KL divergence 1.3303, 50 iterations in 1.4314 sec
# Iteration  250, KL divergence 1.3237, 50 iterations in 1.3868 sec
# Iteration  300, KL divergence 1.3195, 50 iterations in 1.5356 sec
# Iteration  350, KL divergence 1.3163, 50 iterations in 1.6860 sec
# Iteration  400, KL divergence 1.3140, 50 iterations in 1.6622 sec
# Iteration  450, KL divergence 1.3121, 50 iterations in 1.3315 sec
# Iteration  500, KL divergence 1.3103, 50 iterations in 1.4734 sec
#    --> Time elapsed: 14.84 seconds
# n = 1000, d = 50, b=0.15
# Computed h_n = 0.3548
# Using perplexity = 42.38 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 7.94
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=7.943282347242815, exaggeration=7.943282347242815,
#      n_jobs=-1, perplexity=42.37612633868263, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 127 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.24 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.05 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=7.94, lr=125.89 for 250 iterations...
# Iteration   50, KL divergence 1.4734, 50 iterations in 1.6113 sec
# Iteration  100, KL divergence 1.4477, 50 iterations in 1.4556 sec
# Iteration  150, KL divergence 1.4296, 50 iterations in 1.4315 sec
# Iteration  200, KL divergence 1.4189, 50 iterations in 1.8610 sec
# Iteration  250, KL divergence 1.4139, 50 iterations in 1.4876 sec
#    --> Time elapsed: 7.85 seconds
# ===> Running optimization with exaggeration=7.94, lr=125.89 for 500 iterations...
# Iteration   50, KL divergence 1.4094, 50 iterations in 1.6464 sec
# Iteration  100, KL divergence 1.4057, 50 iterations in 1.6184 sec
# Iteration  150, KL divergence 1.4026, 50 iterations in 1.9145 sec
# Iteration  200, KL divergence 1.4004, 50 iterations in 1.7228 sec
# Iteration  250, KL divergence 1.3978, 50 iterations in 1.6254 sec
# Iteration  300, KL divergence 1.3958, 50 iterations in 1.6987 sec
# Iteration  350, KL divergence 1.3939, 50 iterations in 1.6573 sec
# Iteration  400, KL divergence 1.3919, 50 iterations in 1.8513 sec
# Iteration  450, KL divergence 1.3924, 50 iterations in 1.6867 sec
# Iteration  500, KL divergence 1.3911, 50 iterations in 1.4743 sec
#    --> Time elapsed: 16.90 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 4.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.38 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=833.33 for 250 iterations...
# Iteration   50, KL divergence 4.1384, 50 iterations in 1.6146 sec
# Iteration  100, KL divergence 4.0397, 50 iterations in 1.8279 sec
# Iteration  150, KL divergence 4.0069, 50 iterations in 1.5733 sec
# Iteration  200, KL divergence 4.0043, 50 iterations in 1.9712 sec
# Iteration  250, KL divergence 3.9955, 50 iterations in 1.8856 sec
#    --> Time elapsed: 8.87 seconds
# ===> Running optimization with exaggeration=1.00, lr=10000.00 for 500 iterations...
# Iteration   50, KL divergence 3.5330, 50 iterations in 1.8353 sec
# Iteration  100, KL divergence 3.4514, 50 iterations in 1.6522 sec
# Iteration  150, KL divergence 3.4180, 50 iterations in 1.7728 sec
# Iteration  200, KL divergence 3.3983, 50 iterations in 1.9673 sec
# Iteration  250, KL divergence 3.3845, 50 iterations in 2.8801 sec
# Iteration  300, KL divergence 3.3736, 50 iterations in 2.7883 sec
# Iteration  350, KL divergence 3.3646, 50 iterations in 3.8755 sec
# Iteration  400, KL divergence 3.3569, 50 iterations in 3.8008 sec
# Iteration  450, KL divergence 3.3501, 50 iterations in 4.4975 sec
# Iteration  500, KL divergence 3.3442, 50 iterations in 4.6345 sec
#    --> Time elapsed: 29.71 seconds
# n = 10000, d = 50, b=0.15
# Computed h_n = 0.2512
# Using perplexity = 47.55 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 15.85
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=15.848931924611133, exaggeration=15.848931924611133,
#      n_jobs=-1, perplexity=47.54679577383341, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 142 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 5.25 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.60 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=15.85, lr=630.96 for 250 iterations...
# Iteration   50, KL divergence 3.7711, 50 iterations in 2.0095 sec
# Iteration  100, KL divergence 3.6303, 50 iterations in 3.0021 sec
# Iteration  150, KL divergence 3.5850, 50 iterations in 2.4854 sec
# Iteration  200, KL divergence 3.5546, 50 iterations in 2.6316 sec
# Iteration  250, KL divergence 3.5423, 50 iterations in 2.2994 sec
#    --> Time elapsed: 12.43 seconds
# ===> Running optimization with exaggeration=15.85, lr=630.96 for 500 iterations...
# Iteration   50, KL divergence 3.5269, 50 iterations in 2.2737 sec
# Iteration  100, KL divergence 3.5232, 50 iterations in 2.3895 sec
# Iteration  150, KL divergence 3.5266, 50 iterations in 2.2897 sec
# Iteration  200, KL divergence 3.5059, 50 iterations in 2.2302 sec
# Iteration  250, KL divergence 3.5076, 50 iterations in 2.4727 sec
# Iteration  300, KL divergence 3.5027, 50 iterations in 2.7522 sec
# Iteration  350, KL divergence 3.5099, 50 iterations in 2.2873 sec
# Iteration  400, KL divergence 3.4989, 50 iterations in 2.3273 sec
# Iteration  450, KL divergence 3.5024, 50 iterations in 2.3211 sec
# Iteration  500, KL divergence 3.4928, 50 iterations in 2.5219 sec
#    --> Time elapsed: 23.87 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 71.80 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 5.58 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.05 seconds
# ===> Running optimization with exaggeration=12.00, lr=8333.33 for 250 iterations...
# Iteration   50, KL divergence 6.4529, 50 iterations in 13.7072 sec
# Iteration  100, KL divergence 6.3116, 50 iterations in 13.2427 sec
# Iteration  150, KL divergence 6.2766, 50 iterations in 13.6313 sec
# Iteration  200, KL divergence 6.2588, 50 iterations in 13.3739 sec
# Iteration  250, KL divergence 6.2459, 50 iterations in 13.6256 sec
#    --> Time elapsed: 67.58 seconds
# ===> Running optimization with exaggeration=1.00, lr=100000.00 for 500 iterations...
# Iteration   50, KL divergence 5.7679, 50 iterations in 11.2253 sec
# Iteration  100, KL divergence 5.6950, 50 iterations in 10.3211 sec
# Iteration  150, KL divergence 5.6635, 50 iterations in 9.2301 sec
# Iteration  200, KL divergence 5.6455, 50 iterations in 9.2492 sec
# Iteration  250, KL divergence 5.6325, 50 iterations in 9.6099 sec
# Iteration  300, KL divergence 5.6223, 50 iterations in 9.4678 sec
# Iteration  350, KL divergence 5.6136, 50 iterations in 9.8305 sec
# Iteration  400, KL divergence 5.6059, 50 iterations in 10.1113 sec
# Iteration  450, KL divergence 5.5988, 50 iterations in 11.0004 sec
# Iteration  500, KL divergence 5.5923, 50 iterations in 11.0955 sec
#    --> Time elapsed: 101.14 seconds
# n = 100000, d = 50, b=0.15
# Computed h_n = 0.1778
# Using perplexity = 53.35 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 31.62
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=31.62277660168379, exaggeration=31.62277660168379,
#      n_jobs=-1, perplexity=53.34838230116768, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 160 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 67.36 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 7.50 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=31.62, lr=3162.28 for 250 iterations...
# Iteration   50, KL divergence 7.1650, 50 iterations in 13.3838 sec
# Iteration  100, KL divergence 6.1914, 50 iterations in 13.2849 sec
# Iteration  150, KL divergence 5.8743, 50 iterations in 12.9312 sec
# Iteration  200, KL divergence 5.8181, 50 iterations in 12.7603 sec
# Iteration  250, KL divergence 5.7908, 50 iterations in 12.7173 sec
#    --> Time elapsed: 65.08 seconds
# ===> Running optimization with exaggeration=31.62, lr=3162.28 for 500 iterations...
# Iteration   50, KL divergence 5.7680, 50 iterations in 12.7233 sec
# Iteration  100, KL divergence 5.7505, 50 iterations in 12.6037 sec
# Iteration  150, KL divergence 5.7393, 50 iterations in 12.6947 sec
# Iteration  200, KL divergence 5.7313, 50 iterations in 12.4706 sec
# Iteration  250, KL divergence 5.7227, 50 iterations in 12.6137 sec
# Iteration  300, KL divergence 5.7130, 50 iterations in 12.7037 sec
# Iteration  350, KL divergence 5.7112, 50 iterations in 12.6445 sec
# Iteration  400, KL divergence 5.7066, 50 iterations in 12.8354 sec
# Iteration  450, KL divergence 5.7078, 50 iterations in 12.8461 sec
# Iteration  500, KL divergence 5.7004, 50 iterations in 12.7707 sec
#    --> Time elapsed: 126.91 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=8.33 for 250 iterations...
# Iteration   50, KL divergence 1.0155, 50 iterations in 0.0772 sec
# Iteration  100, KL divergence 1.0673, 50 iterations in 0.0755 sec
# Iteration  150, KL divergence 0.9953, 50 iterations in 0.1004 sec
# Iteration  200, KL divergence 1.0388, 50 iterations in 0.0472 sec
# Iteration  250, KL divergence 1.0292, 50 iterations in 0.0477 sec
#    --> Time elapsed: 0.35 seconds
# ===> Running optimization with exaggeration=1.00, lr=100.00 for 500 iterations...
# Iteration   50, KL divergence 0.0509, 50 iterations in 0.0593 sec
# Iteration  100, KL divergence 0.0088, 50 iterations in 0.0664 sec
# Iteration  150, KL divergence 0.0068, 50 iterations in 0.0555 sec
# Iteration  200, KL divergence 0.0067, 50 iterations in 0.0556 sec
# Iteration  250, KL divergence 0.0067, 50 iterations in 0.0541 sec
# Iteration  300, KL divergence 0.0067, 50 iterations in 0.0574 sec
# Iteration  350, KL divergence 0.0068, 50 iterations in 0.0552 sec
# Iteration  400, KL divergence 0.0068, 50 iterations in 0.0531 sec
# Iteration  450, KL divergence 0.0068, 50 iterations in 0.0525 sec
# Perplexity value 37 is too high. Using perplexity 33.00 instead
# Iteration  500, KL divergence 0.0068, 50 iterations in 0.0580 sec
#    --> Time elapsed: 0.57 seconds
# n = 100, d = 50, b=0.05
# Computed h_n = 0.7943
# Using perplexity = 37.77 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 1.58
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=1.5848931924611134, exaggeration=1.5848931924611134,
#      n_jobs=-1, perplexity=37.76776235382502, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 99 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.58, lr=63.10 for 250 iterations...
# Iteration   50, KL divergence 0.0105, 50 iterations in 0.0964 sec
# Iteration  100, KL divergence 0.0259, 50 iterations in 0.0995 sec
# Iteration  150, KL divergence 0.0267, 50 iterations in 0.0785 sec
# Iteration  200, KL divergence 0.0267, 50 iterations in 0.0687 sec
# Iteration  250, KL divergence 0.0267, 50 iterations in 0.0708 sec
#    --> Time elapsed: 0.41 seconds
# ===> Running optimization with exaggeration=1.58, lr=63.10 for 500 iterations...
# Iteration   50, KL divergence 0.0267, 50 iterations in 0.0686 sec
# Iteration  100, KL divergence 0.0267, 50 iterations in 0.0692 sec
# Iteration  150, KL divergence 0.0267, 50 iterations in 0.0699 sec
# Iteration  200, KL divergence 0.0267, 50 iterations in 0.0773 sec
# Iteration  250, KL divergence 0.0267, 50 iterations in 0.0684 sec
# Iteration  300, KL divergence 0.0267, 50 iterations in 0.0681 sec
# Iteration  350, KL divergence 0.0267, 50 iterations in 0.0704 sec
# Iteration  400, KL divergence 0.0267, 50 iterations in 0.0691 sec
# Iteration  450, KL divergence 0.0267, 50 iterations in 0.0742 sec
# Iteration  500, KL divergence 0.0267, 50 iterations in 0.0709 sec
#    --> Time elapsed: 0.71 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=41.67 for 250 iterations...
# Iteration   50, KL divergence 1.1987, 50 iterations in 0.5158 sec
# Iteration  100, KL divergence 1.1539, 50 iterations in 0.4936 sec
# Iteration  150, KL divergence 1.1276, 50 iterations in 0.5337 sec
# Iteration  200, KL divergence 1.1134, 50 iterations in 0.5223 sec
# Iteration  250, KL divergence 1.1025, 50 iterations in 0.5135 sec
#    --> Time elapsed: 2.58 seconds
# ===> Running optimization with exaggeration=1.00, lr=500.00 for 500 iterations...
# Iteration   50, KL divergence 0.8558, 50 iterations in 0.4423 sec
# Iteration  100, KL divergence 0.8163, 50 iterations in 0.4475 sec
# Iteration  150, KL divergence 0.8024, 50 iterations in 0.4405 sec
# Iteration  200, KL divergence 0.7957, 50 iterations in 0.4525 sec
# Iteration  250, KL divergence 0.7909, 50 iterations in 0.4394 sec
# Iteration  300, KL divergence 0.7878, 50 iterations in 0.4446 sec
# Iteration  350, KL divergence 0.7859, 50 iterations in 0.4496 sec
# Iteration  400, KL divergence 0.7840, 50 iterations in 0.4458 sec
# Iteration  450, KL divergence 0.7831, 50 iterations in 0.4526 sec
# Iteration  500, KL divergence 0.7820, 50 iterations in 0.4515 sec
#    --> Time elapsed: 4.47 seconds
# n = 500, d = 50, b=0.05
# Computed h_n = 0.7329
# Using perplexity = 40.93 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 1.86
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=1.8616455666360698, exaggeration=1.8616455666360698,
#      n_jobs=-1, perplexity=40.93263990964255, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 122 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=1.86, lr=268.58 for 250 iterations...
# Iteration   50, KL divergence 0.7971, 50 iterations in 0.5307 sec
# Iteration  100, KL divergence 0.7893, 50 iterations in 0.5338 sec
# Iteration  150, KL divergence 0.7828, 50 iterations in 0.5118 sec
# Iteration  200, KL divergence 0.7788, 50 iterations in 0.4859 sec
# Iteration  250, KL divergence 0.7761, 50 iterations in 0.5078 sec
#    --> Time elapsed: 2.57 seconds
# ===> Running optimization with exaggeration=1.86, lr=268.58 for 500 iterations...
# Iteration   50, KL divergence 0.7741, 50 iterations in 0.5113 sec
# Iteration  100, KL divergence 0.7726, 50 iterations in 0.5003 sec
# Iteration  150, KL divergence 0.7715, 50 iterations in 0.5090 sec
# Iteration  200, KL divergence 0.7705, 50 iterations in 0.5279 sec
# Iteration  250, KL divergence 0.7697, 50 iterations in 0.5041 sec
# Iteration  300, KL divergence 0.7689, 50 iterations in 0.5300 sec
# Iteration  350, KL divergence 0.7683, 50 iterations in 0.5072 sec
# Iteration  400, KL divergence 0.7677, 50 iterations in 0.5156 sec
# Iteration  450, KL divergence 0.7672, 50 iterations in 0.5184 sec
# Iteration  500, KL divergence 0.7668, 50 iterations in 0.5555 sec
#    --> Time elapsed: 5.18 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.17 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.03 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=83.33 for 250 iterations...
# Iteration   50, KL divergence 1.8391, 50 iterations in 1.1549 sec
# Iteration  100, KL divergence 1.7905, 50 iterations in 1.1483 sec
# Iteration  150, KL divergence 1.7633, 50 iterations in 1.1763 sec
# Iteration  200, KL divergence 1.7500, 50 iterations in 1.2001 sec
# Iteration  250, KL divergence 1.7404, 50 iterations in 1.2078 sec
#    --> Time elapsed: 5.89 seconds
# ===> Running optimization with exaggeration=1.00, lr=1000.00 for 500 iterations...
# Iteration   50, KL divergence 1.4178, 50 iterations in 1.0872 sec
# Iteration  100, KL divergence 1.3624, 50 iterations in 1.0742 sec
# Iteration  150, KL divergence 1.3404, 50 iterations in 1.1024 sec
# Iteration  200, KL divergence 1.3303, 50 iterations in 1.1013 sec
# Iteration  250, KL divergence 1.3237, 50 iterations in 1.0977 sec
# Iteration  300, KL divergence 1.3195, 50 iterations in 1.0862 sec
# Iteration  350, KL divergence 1.3163, 50 iterations in 1.0966 sec
# Iteration  400, KL divergence 1.3140, 50 iterations in 1.0616 sec
# Iteration  450, KL divergence 1.3121, 50 iterations in 1.0669 sec
# Iteration  500, KL divergence 1.3103, 50 iterations in 1.0903 sec
#    --> Time elapsed: 10.87 seconds
# n = 1000, d = 50, b=0.05
# Computed h_n = 0.7079
# Using perplexity = 42.38 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 2.00
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=1.9952623149688797, exaggeration=1.9952623149688797,
#      n_jobs=-1, perplexity=42.37612633868263, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 127 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.17 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=2.00, lr=501.19 for 250 iterations...
# Iteration   50, KL divergence 1.3928, 50 iterations in 1.3986 sec
# Iteration  100, KL divergence 1.3846, 50 iterations in 1.1930 sec
# Iteration  150, KL divergence 1.3777, 50 iterations in 1.2235 sec
# Iteration  200, KL divergence 1.3730, 50 iterations in 1.2073 sec
# Iteration  250, KL divergence 1.3698, 50 iterations in 1.2613 sec
#    --> Time elapsed: 6.28 seconds
# ===> Running optimization with exaggeration=2.00, lr=501.19 for 500 iterations...
# Iteration   50, KL divergence 1.3675, 50 iterations in 1.2439 sec
# Iteration  100, KL divergence 1.3656, 50 iterations in 1.2027 sec
# Iteration  150, KL divergence 1.3641, 50 iterations in 1.2479 sec
# Iteration  200, KL divergence 1.3629, 50 iterations in 1.2952 sec
# Iteration  250, KL divergence 1.3618, 50 iterations in 1.2640 sec
# Iteration  300, KL divergence 1.3609, 50 iterations in 1.2293 sec
# Iteration  350, KL divergence 1.3601, 50 iterations in 1.2442 sec
# Iteration  400, KL divergence 1.3594, 50 iterations in 1.3426 sec
# Iteration  450, KL divergence 1.3588, 50 iterations in 1.2377 sec
# Iteration  500, KL divergence 1.3583, 50 iterations in 1.2288 sec
#    --> Time elapsed: 12.54 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 2.57 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.45 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=833.33 for 250 iterations...
# Iteration   50, KL divergence 4.1384, 50 iterations in 1.2848 sec
# Iteration  100, KL divergence 4.0397, 50 iterations in 1.2999 sec
# Iteration  150, KL divergence 4.0069, 50 iterations in 1.3020 sec
# Iteration  200, KL divergence 4.0043, 50 iterations in 1.2618 sec
# Iteration  250, KL divergence 3.9955, 50 iterations in 1.3175 sec
#    --> Time elapsed: 6.47 seconds
# ===> Running optimization with exaggeration=1.00, lr=10000.00 for 500 iterations...
# Iteration   50, KL divergence 3.5330, 50 iterations in 1.2739 sec
# Iteration  100, KL divergence 3.4514, 50 iterations in 1.4135 sec
# Iteration  150, KL divergence 3.4180, 50 iterations in 1.2923 sec
# Iteration  200, KL divergence 3.3983, 50 iterations in 1.5944 sec
# Iteration  250, KL divergence 3.3845, 50 iterations in 1.9914 sec
# Iteration  300, KL divergence 3.3736, 50 iterations in 2.8897 sec
# Iteration  350, KL divergence 3.3646, 50 iterations in 2.7494 sec
# Iteration  400, KL divergence 3.3569, 50 iterations in 3.2433 sec
# Iteration  450, KL divergence 3.3501, 50 iterations in 3.3870 sec
# Iteration  500, KL divergence 3.3442, 50 iterations in 3.7261 sec
#    --> Time elapsed: 23.56 seconds
# n = 10000, d = 50, b=0.05
# Computed h_n = 0.6310
# Using perplexity = 47.55 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 2.51
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=2.51188643150958, exaggeration=2.51188643150958,
#      n_jobs=-1, perplexity=47.54679577383341, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 142 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 3.54 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.48 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=2.51, lr=3981.07 for 250 iterations...
# Iteration   50, KL divergence 3.5235, 50 iterations in 1.5811 sec
# Iteration  100, KL divergence 3.4983, 50 iterations in 1.6089 sec
# Iteration  150, KL divergence 3.4828, 50 iterations in 1.6929 sec
# Iteration  200, KL divergence 3.4842, 50 iterations in 1.5457 sec
# Iteration  250, KL divergence 3.4694, 50 iterations in 1.5429 sec
#    --> Time elapsed: 7.97 seconds
# ===> Running optimization with exaggeration=2.51, lr=3981.07 for 500 iterations...
# Iteration   50, KL divergence 3.4697, 50 iterations in 1.5227 sec
# Iteration  100, KL divergence 3.4671, 50 iterations in 1.7412 sec
# Iteration  150, KL divergence 3.4663, 50 iterations in 1.6223 sec
# Iteration  200, KL divergence 3.4642, 50 iterations in 1.7208 sec
# Iteration  250, KL divergence 3.4593, 50 iterations in 1.5228 sec
# Iteration  300, KL divergence 3.4589, 50 iterations in 1.5513 sec
# Iteration  350, KL divergence 3.4444, 50 iterations in 1.6442 sec
# Iteration  400, KL divergence 3.4455, 50 iterations in 1.5230 sec
# Iteration  450, KL divergence 3.4748, 50 iterations in 1.5496 sec
# Iteration  500, KL divergence 3.4587, 50 iterations in 1.5302 sec
#    --> Time elapsed: 15.94 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 46.35 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 3.54 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=8333.33 for 250 iterations...
# Iteration   50, KL divergence 6.4529, 50 iterations in 8.4590 sec
# Iteration  100, KL divergence 6.3116, 50 iterations in 8.5597 sec
# Iteration  150, KL divergence 6.2766, 50 iterations in 8.5066 sec
# Iteration  200, KL divergence 6.2588, 50 iterations in 8.4123 sec
# Iteration  250, KL divergence 6.2459, 50 iterations in 8.2001 sec
#    --> Time elapsed: 42.14 seconds
# ===> Running optimization with exaggeration=1.00, lr=100000.00 for 500 iterations...
# Iteration   50, KL divergence 5.7679, 50 iterations in 8.3543 sec
# Iteration  100, KL divergence 5.6950, 50 iterations in 8.3522 sec
# Iteration  150, KL divergence 5.6635, 50 iterations in 8.0354 sec
# Iteration  200, KL divergence 5.6455, 50 iterations in 8.3560 sec
# Iteration  250, KL divergence 5.6325, 50 iterations in 8.7295 sec
# Iteration  300, KL divergence 5.6223, 50 iterations in 8.9841 sec
# Iteration  350, KL divergence 5.6136, 50 iterations in 9.5725 sec
# Iteration  400, KL divergence 5.6059, 50 iterations in 9.5345 sec
# Iteration  450, KL divergence 5.5988, 50 iterations in 10.1912 sec
# Iteration  500, KL divergence 5.5923, 50 iterations in 10.2660 sec
#    --> Time elapsed: 90.38 seconds
# n = 100000, d = 50, b=0.05
# Computed h_n = 0.5623
# Using perplexity = 53.35 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 3.16
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=3.162277660168379, exaggeration=3.162277660168379,
#      n_jobs=-1, perplexity=53.34838230116768, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 160 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 65.03 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 6.68 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=3.16, lr=31622.78 for 250 iterations...
# Iteration   50, KL divergence 5.6755, 50 iterations in 13.6689 sec
# Iteration  100, KL divergence 5.6729, 50 iterations in 13.1728 sec
# Iteration  150, KL divergence 5.6523, 50 iterations in 13.0557 sec
# Iteration  200, KL divergence 5.6534, 50 iterations in 12.9504 sec
# Iteration  250, KL divergence 5.6422, 50 iterations in 12.9857 sec
#    --> Time elapsed: 65.83 seconds
# ===> Running optimization with exaggeration=3.16, lr=31622.78 for 500 iterations...
# Iteration   50, KL divergence 5.6535, 50 iterations in 12.6426 sec
# Iteration  100, KL divergence 5.6299, 50 iterations in 12.7311 sec
# Iteration  150, KL divergence 5.6245, 50 iterations in 12.7969 sec
# Iteration  200, KL divergence 5.6404, 50 iterations in 12.5937 sec
# Iteration  250, KL divergence 5.6346, 50 iterations in 12.9280 sec
# Iteration  300, KL divergence 5.6236, 50 iterations in 12.5778 sec
# Iteration  350, KL divergence 5.6351, 50 iterations in 12.7965 sec
# Iteration  400, KL divergence 5.6179, 50 iterations in 12.6682 sec
# Iteration  450, KL divergence 5.6343, 50 iterations in 12.4988 sec
# Iteration  500, KL divergence 5.6182, 50 iterations in 12.6995 sec
#    --> Time elapsed: 126.94 seconds

# %% [markdown]
# ### More Helper Functions

# %%
def generate_tsne_embeddings(data_sizes, dim=50, n_components=5, b=0.15):
    """
    Generates Gaussian mixture data and computes both standard and rescaled t-SNE embeddings.

    Parameters:
    - data_sizes (list): List of sample sizes to generate.
    - dim (int): Dimensionality of the generated data (default: 50).
    - n_components (int): Number of Gaussian components in the mixture (default: 5).
    - b (float): Scaling parameter for rescaled t-SNE (default: 0.15).

    Returns:
    - embeddings (list of tuples): Each tuple contains (standard_tsne, rescaled_tsne, labels).
    """
    embeddings = []
    for n_fixed in data_sizes:
        # Generate synthetic data
        data_sample, labels = sample_gaussian_mixture(n_samples=n_fixed, dim=dim, n_components=n_components)
        
        # Compute embeddings
        emb_standard = run_standard_tsne_improved(data_sample)
        emb_rescaled = run_rescaled_tsne_improved(data_sample, kappa=30, alpha=0.05, b=b)
        
        embeddings.append((emb_standard, emb_rescaled, labels))
    
    return embeddings

# %%
def plot_scatterplots(data_sizes, embeddings):
    """
    Plots scatterplots of standard and rescaled t-SNE embeddings.

    Parameters:
    - data_sizes (list): List of sample sizes used.
    - embeddings (list of tuples): Contains (standard_tsne, rescaled_tsne, labels).
    """
    num_rows = len(data_sizes)
    fig, axes = plt.subplots(num_rows, 2, figsize=(10, 5 * num_rows))
    fig.suptitle("Standard vs. Rescaled t-SNE", fontsize=14, y=1.02)

    for i, (emb_standard, emb_rescaled, labels) in enumerate(embeddings):
        # Scatter plot for standard t-SNE
        axes[i, 0].scatter(emb_standard[:, 0], emb_standard[:, 1], c=labels, cmap="Set1", s=5)
        axes[i, 0].set_title(f"Standard t-SNE ({data_sizes[i]} points)")

        # Scatter plot for rescaled t-SNE
        axes[i, 1].scatter(emb_rescaled[:, 0], emb_rescaled[:, 1], c=labels, cmap="Set1", s=5)
        axes[i, 1].set_title(f"Rescaled t-SNE ({data_sizes[i]} points)")

    plt.tight_layout()
    plt.show()

# %%
def plot_density_histograms(data_sizes, embeddings, bins=100):
    """
    Plots 2D density histograms (heatmaps) for standard and rescaled t-SNE embeddings.
    
    Parameters:
    - data_sizes (list): List of sample sizes used.
    - embeddings (list of tuples): Contains (standard_tsne, rescaled_tsne, labels).
    - bins (int): Number of bins for 2D histogram (default: 100).
    """
    num_rows = len(data_sizes)
    fig, axes = plt.subplots(num_rows, 2, figsize=(10, 5 * num_rows))
    fig.suptitle("Density Histograms Comparison", fontsize=14, y=1.02)

    for i, (emb_standard, emb_rescaled, _) in enumerate(embeddings):
        # Density histogram for standard t-SNE
        ax1 = axes[i, 0]
        ax1.hist2d(emb_standard[:, 0], emb_standard[:, 1], bins=bins, cmap="magma")
        ax1.set_title(f"Standard t-SNE ({data_sizes[i]} points)")

        # Density histogram for rescaled t-SNE
        ax2 = axes[i, 1]
        ax2.hist2d(emb_rescaled[:, 0], emb_rescaled[:, 1], bins=bins, cmap="magma")
        ax2.set_title(f"Rescaled t-SNE ({data_sizes[i]} points)")

    plt.tight_layout()
    plt.show()

# %%
# Main function to run everything
def compare_all(data_sizes, dim=50, n_components=5, b=0.15):
    """
    Orchestrates the generation, scatterplot visualization, and density histogram visualization
    of standard vs. rescaled t-SNE embeddings.
    """
    embeddings = generate_tsne_embeddings(data_sizes, dim, n_components, b)
    plot_scatterplots(data_sizes, embeddings)
    plot_density_histograms(data_sizes, embeddings)

# %% [markdown]
# ### more experiments

# %%
data_sizes = [100, 500, 1000, 10000]
embeddings = generate_tsne_embeddings(data_sizes)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=8.33 for 250 iterations...
# Iteration   50, KL divergence 1.0155, 50 iterations in 0.0883 sec
# Iteration  100, KL divergence 1.0673, 50 iterations in 0.0958 sec
# Iteration  150, KL divergence 0.9953, 50 iterations in 0.0830 sec
# Iteration  200, KL divergence 1.0388, 50 iterations in 0.0594 sec
# Iteration  250, KL divergence 1.0292, 50 iterations in 0.0608 sec
#    --> Time elapsed: 0.39 seconds
# ===> Running optimization with exaggeration=1.00, lr=100.00 for 500 iterations...
# Iteration   50, KL divergence 0.0509, 50 iterations in 0.0873 sec
# Iteration  100, KL divergence 0.0088, 50 iterations in 0.0946 sec
# Iteration  150, KL divergence 0.0068, 50 iterations in 0.0784 sec
# Iteration  200, KL divergence 0.0067, 50 iterations in 0.0755 sec
# Iteration  250, KL divergence 0.0067, 50 iterations in 0.1612 sec
# Iteration  300, KL divergence 0.0067, 50 iterations in 0.2758 sec
# Iteration  350, KL divergence 0.0068, 50 iterations in 0.1566 sec
# Iteration  400, KL divergence 0.0068, 50 iterations in 0.1478 sec
# Iteration  450, KL divergence 0.0068, 50 iterations in 0.1897 sec
# Perplexity value 37 is too high. Using perplexity 33.00 instead
# Iteration  500, KL divergence 0.0068, 50 iterations in 0.1214 sec
#    --> Time elapsed: 1.39 seconds
# n = 100, d = 50, b=0.15
# Computed h_n = 0.5012
# Using perplexity = 37.77 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 3.98
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=3.981071705534973, exaggeration=3.981071705534973,
#      n_jobs=-1, perplexity=37.76776235382502, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 99 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=3.98, lr=25.12 for 250 iterations...
# Iteration   50, KL divergence 0.3647, 50 iterations in 0.1346 sec
# Iteration  100, KL divergence 0.3207, 50 iterations in 0.1102 sec
# Iteration  150, KL divergence 0.3205, 50 iterations in 0.0861 sec
# Iteration  200, KL divergence 0.3206, 50 iterations in 0.0788 sec
# Iteration  250, KL divergence 0.3206, 50 iterations in 0.0850 sec
#    --> Time elapsed: 0.50 seconds
# ===> Running optimization with exaggeration=3.98, lr=25.12 for 500 iterations...
# Iteration   50, KL divergence 0.3206, 50 iterations in 0.0746 sec
# Iteration  100, KL divergence 0.3206, 50 iterations in 0.0750 sec
# Iteration  150, KL divergence 0.3206, 50 iterations in 0.0873 sec
# Iteration  200, KL divergence 0.3206, 50 iterations in 0.1021 sec
# Iteration  250, KL divergence 0.3206, 50 iterations in 0.0970 sec
# Iteration  300, KL divergence 0.3206, 50 iterations in 0.1041 sec
# Iteration  350, KL divergence 0.3206, 50 iterations in 0.0907 sec
# Iteration  400, KL divergence 0.3206, 50 iterations in 0.0749 sec
# Iteration  450, KL divergence 0.3206, 50 iterations in 0.0819 sec
# Iteration  500, KL divergence 0.3206, 50 iterations in 0.0796 sec
#    --> Time elapsed: 0.87 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=41.67 for 250 iterations...
# Iteration   50, KL divergence 1.1987, 50 iterations in 0.6223 sec
# Iteration  100, KL divergence 1.1539, 50 iterations in 0.5472 sec
# Iteration  150, KL divergence 1.1276, 50 iterations in 0.5698 sec
# Iteration  200, KL divergence 1.1134, 50 iterations in 0.6178 sec
# Iteration  250, KL divergence 1.1025, 50 iterations in 0.6547 sec
#    --> Time elapsed: 3.01 seconds
# ===> Running optimization with exaggeration=1.00, lr=500.00 for 500 iterations...
# Iteration   50, KL divergence 0.8558, 50 iterations in 1.6017 sec
# Iteration  100, KL divergence 0.8163, 50 iterations in 1.0089 sec
# Iteration  150, KL divergence 0.8024, 50 iterations in 1.2480 sec
# Iteration  200, KL divergence 0.7957, 50 iterations in 1.2271 sec
# Iteration  250, KL divergence 0.7909, 50 iterations in 0.8063 sec
# Iteration  300, KL divergence 0.7878, 50 iterations in 0.5247 sec
# Iteration  350, KL divergence 0.7859, 50 iterations in 0.5449 sec
# Iteration  400, KL divergence 0.7840, 50 iterations in 0.5191 sec
# Iteration  450, KL divergence 0.7831, 50 iterations in 0.5301 sec
# Iteration  500, KL divergence 0.7820, 50 iterations in 0.5258 sec
#    --> Time elapsed: 8.54 seconds
# n = 500, d = 50, b=0.15
# Computed h_n = 0.3937
# Using perplexity = 40.93 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 6.45
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=6.4519501214821595, exaggeration=6.4519501214821595,
#      n_jobs=-1, perplexity=40.93263990964255, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 122 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.02 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=6.45, lr=77.50 for 250 iterations...
# Iteration   50, KL divergence 0.8565, 50 iterations in 0.6151 sec
# Iteration  100, KL divergence 0.8392, 50 iterations in 0.6052 sec
# Iteration  150, KL divergence 0.8242, 50 iterations in 0.5892 sec
# Iteration  200, KL divergence 0.8156, 50 iterations in 0.6025 sec
# Iteration  250, KL divergence 0.8099, 50 iterations in 0.6070 sec
#    --> Time elapsed: 3.02 seconds
# ===> Running optimization with exaggeration=6.45, lr=77.50 for 500 iterations...
# Iteration   50, KL divergence 0.8058, 50 iterations in 0.6239 sec
# Iteration  100, KL divergence 0.8027, 50 iterations in 0.6308 sec
# Iteration  150, KL divergence 0.8002, 50 iterations in 0.6023 sec
# Iteration  200, KL divergence 0.7982, 50 iterations in 0.6279 sec
# Iteration  250, KL divergence 0.7964, 50 iterations in 0.6107 sec
# Iteration  300, KL divergence 0.7948, 50 iterations in 0.6092 sec
# Iteration  350, KL divergence 0.7937, 50 iterations in 0.7071 sec
# Iteration  400, KL divergence 0.7925, 50 iterations in 0.6309 sec
# Iteration  450, KL divergence 0.7915, 50 iterations in 0.6150 sec
# Iteration  500, KL divergence 0.7906, 50 iterations in 0.8733 sec
#    --> Time elapsed: 6.53 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.24 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=12.00, lr=83.33 for 250 iterations...
# Iteration   50, KL divergence 1.8391, 50 iterations in 1.4133 sec
# Iteration  100, KL divergence 1.7905, 50 iterations in 1.7506 sec
# Iteration  150, KL divergence 1.7633, 50 iterations in 1.7356 sec
# Iteration  200, KL divergence 1.7500, 50 iterations in 1.7960 sec
# Iteration  250, KL divergence 1.7404, 50 iterations in 1.8154 sec
#    --> Time elapsed: 8.51 seconds
# ===> Running optimization with exaggeration=1.00, lr=1000.00 for 500 iterations...
# Iteration   50, KL divergence 1.4178, 50 iterations in 1.4297 sec
# Iteration  100, KL divergence 1.3624, 50 iterations in 1.3211 sec
# Iteration  150, KL divergence 1.3404, 50 iterations in 1.7146 sec
# Iteration  200, KL divergence 1.3303, 50 iterations in 2.1237 sec
# Iteration  250, KL divergence 1.3237, 50 iterations in 2.5919 sec
# Iteration  300, KL divergence 1.3195, 50 iterations in 1.9573 sec
# Iteration  350, KL divergence 1.3163, 50 iterations in 2.1357 sec
# Iteration  400, KL divergence 1.3140, 50 iterations in 3.8876 sec
# Iteration  450, KL divergence 1.3121, 50 iterations in 2.1170 sec
# Iteration  500, KL divergence 1.3103, 50 iterations in 3.5152 sec
#    --> Time elapsed: 22.80 seconds
# n = 1000, d = 50, b=0.15
# Computed h_n = 0.3548
# Using perplexity = 42.38 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 7.94
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=7.943282347242815, exaggeration=7.943282347242815,
#      n_jobs=-1, perplexity=42.37612633868263, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 127 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 0.31 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.06 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=7.94, lr=125.89 for 250 iterations...
# Iteration   50, KL divergence 1.4734, 50 iterations in 2.1940 sec
# Iteration  100, KL divergence 1.4477, 50 iterations in 3.8134 sec
# Iteration  150, KL divergence 1.4296, 50 iterations in 4.5226 sec
# Iteration  200, KL divergence 1.4189, 50 iterations in 3.6565 sec
# Iteration  250, KL divergence 1.4139, 50 iterations in 2.4989 sec
#    --> Time elapsed: 16.69 seconds
# ===> Running optimization with exaggeration=7.94, lr=125.89 for 500 iterations...
# Iteration   50, KL divergence 1.4094, 50 iterations in 3.5960 sec
# Iteration  100, KL divergence 1.4057, 50 iterations in 3.4606 sec
# Iteration  150, KL divergence 1.4026, 50 iterations in 2.0295 sec
# Iteration  200, KL divergence 1.4004, 50 iterations in 2.0440 sec
# Iteration  250, KL divergence 1.3978, 50 iterations in 2.3638 sec
# Iteration  300, KL divergence 1.3958, 50 iterations in 1.8212 sec
# Iteration  350, KL divergence 1.3939, 50 iterations in 1.7906 sec
# Iteration  400, KL divergence 1.3919, 50 iterations in 1.7228 sec
# Iteration  450, KL divergence 1.3924, 50 iterations in 3.0660 sec
# Iteration  500, KL divergence 1.3911, 50 iterations in 2.5931 sec
#    --> Time elapsed: 24.49 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 5.10 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.49 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.02 seconds
# ===> Running optimization with exaggeration=12.00, lr=833.33 for 250 iterations...
# Iteration   50, KL divergence 4.1384, 50 iterations in 2.7047 sec
# Iteration  100, KL divergence 4.0397, 50 iterations in 2.1712 sec
# Iteration  150, KL divergence 4.0069, 50 iterations in 2.3760 sec
# Iteration  200, KL divergence 4.0043, 50 iterations in 1.9054 sec
# Iteration  250, KL divergence 3.9955, 50 iterations in 1.9769 sec
#    --> Time elapsed: 11.14 seconds
# ===> Running optimization with exaggeration=1.00, lr=10000.00 for 500 iterations...
# Iteration   50, KL divergence 3.5330, 50 iterations in 1.9619 sec
# Iteration  100, KL divergence 3.4514, 50 iterations in 1.8834 sec
# Iteration  150, KL divergence 3.4180, 50 iterations in 1.9939 sec
# Iteration  200, KL divergence 3.3983, 50 iterations in 2.2323 sec
# Iteration  250, KL divergence 3.3845, 50 iterations in 3.1040 sec
# Iteration  300, KL divergence 3.3736, 50 iterations in 3.1906 sec
# Iteration  350, KL divergence 3.3646, 50 iterations in 3.6188 sec
# Iteration  400, KL divergence 3.3569, 50 iterations in 4.3854 sec
# Iteration  450, KL divergence 3.3501, 50 iterations in 5.0747 sec
# Iteration  500, KL divergence 3.3442, 50 iterations in 4.7486 sec
#    --> Time elapsed: 32.20 seconds
# n = 10000, d = 50, b=0.15
# Computed h_n = 0.2512
# Using perplexity = 47.55 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 15.85
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=15.848931924611133, exaggeration=15.848931924611133,
#      n_jobs=-1, perplexity=47.54679577383341, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 142 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 5.28 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.71 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.00 seconds
# ===> Running optimization with exaggeration=15.85, lr=630.96 for 250 iterations...
# Iteration   50, KL divergence 3.7711, 50 iterations in 2.5190 sec
# Iteration  100, KL divergence 3.6303, 50 iterations in 2.3296 sec
# Iteration  150, KL divergence 3.5850, 50 iterations in 2.2859 sec
# Iteration  200, KL divergence 3.5546, 50 iterations in 2.2106 sec
# Iteration  250, KL divergence 3.5423, 50 iterations in 2.2605 sec
#    --> Time elapsed: 11.61 seconds
# ===> Running optimization with exaggeration=15.85, lr=630.96 for 500 iterations...
# Iteration   50, KL divergence 3.5269, 50 iterations in 3.3937 sec
# Iteration  100, KL divergence 3.5232, 50 iterations in 2.7776 sec
# Iteration  150, KL divergence 3.5266, 50 iterations in 2.1734 sec
# Iteration  200, KL divergence 3.5059, 50 iterations in 2.2665 sec
# Iteration  250, KL divergence 3.5076, 50 iterations in 2.6375 sec
# Iteration  300, KL divergence 3.5027, 50 iterations in 2.3089 sec
# Iteration  350, KL divergence 3.5099, 50 iterations in 2.3052 sec
# Iteration  400, KL divergence 3.4989, 50 iterations in 2.5416 sec
# Iteration  450, KL divergence 3.5024, 50 iterations in 2.2952 sec
# Iteration  500, KL divergence 3.4928, 50 iterations in 2.3218 sec
#    --> Time elapsed: 25.02 seconds

# %%
plot_scatterplots(data_sizes, embeddings)

# %%
plot_density_histograms(data_sizes, embeddings, bins=50)

# %% [markdown]
# ## trying rescaled t-SNE on real data

# %% [markdown]
# ### load data

# %%
from keras.datasets import mnist
import pandas as pd 
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# preprocessing MNIST data 
mnist_data = np.zeros((x_train.shape[0], 784))
for i in range(x_train.shape[0]):
    mnist_data[i] = x_train[i].flatten()
mnist_data = pd.DataFrame(mnist_data)
mnist_labels = pd.DataFrame(y_train)

# %%
def sample_mnist_data(percentage, random_state=12): 
    X_sample = mnist_data.sample(frac=percentage, random_state=random_state).reset_index(drop=True)
    Y_sample = mnist_labels.sample(frac=percentage, random_state=random_state).reset_index(drop=True)
    return X_sample, Y_sample

# %%
def generate_mnist_embeddings(percentages, b=0.15, kappa=30):
    """
    Generates Gaussian mixture data and computes both standard and rescaled t-SNE embeddings.

    Parameters:
    - data_sizes (list): List of sample sizes to generate.
    - dim (int): Dimensionality of the generated data (default: 50).
    - n_components (int): Number of Gaussian components in the mixture (default: 5).
    - b (float): Scaling parameter for rescaled t-SNE (default: 0.15).

    Returns:
    - embeddings (list of tuples): Each tuple contains (standard_tsne, rescaled_tsne, labels).
    """
    embeddings = []
    for percentage in percentages:
        # Generate synthetic data
        data_sample, labels = sample_mnist_data(percentage)
        
        # Compute embeddings
        emb_standard = run_standard_tsne_improved(data_sample.to_numpy())
        emb_rescaled = run_rescaled_tsne_improved(data_sample.to_numpy(), kappa=kappa, alpha=0.05, b=b)
        
        embeddings.append((emb_standard, emb_rescaled, labels))
    
    return embeddings

# %%
percentages = [0.01, 0.1]
embeddings = generate_mnist_embeddings(percentages)
# Out:
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.08 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=50.00 for 250 iterations...
# Iteration   50, KL divergence 2.1947, 50 iterations in 1.5697 sec
# Iteration  100, KL divergence 2.5074, 50 iterations in 1.9295 sec
# Iteration  150, KL divergence 2.4598, 50 iterations in 1.0230 sec
# Iteration  200, KL divergence 2.4808, 50 iterations in 0.9362 sec
# Iteration  250, KL divergence 2.4783, 50 iterations in 0.7466 sec
#    --> Time elapsed: 6.21 seconds
# ===> Running optimization with exaggeration=1.00, lr=600.00 for 500 iterations...
# Iteration   50, KL divergence 1.0105, 50 iterations in 1.0118 sec
# Iteration  100, KL divergence 0.9649, 50 iterations in 1.0658 sec
# Iteration  150, KL divergence 0.9448, 50 iterations in 1.1205 sec
# Iteration  200, KL divergence 0.9335, 50 iterations in 1.0666 sec
# Iteration  250, KL divergence 0.9249, 50 iterations in 0.8776 sec
# Iteration  300, KL divergence 0.9200, 50 iterations in 0.8590 sec
# Iteration  350, KL divergence 0.9168, 50 iterations in 0.8540 sec
# Iteration  400, KL divergence 0.9157, 50 iterations in 0.8591 sec
# Iteration  450, KL divergence 0.9147, 50 iterations in 0.8182 sec
# Iteration  500, KL divergence 0.9123, 50 iterations in 0.8445 sec
#    --> Time elapsed: 9.38 seconds
# n = 600, d = 784, b=0.15
# Computed h_n = 0.3831
# Using perplexity = 41.31 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 6.81
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=6.814678553683554, exaggeration=6.814678553683554,
#      n_jobs=-1, perplexity=41.30749103131467, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 123 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.10 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.05 seconds
# ===> Running optimization with exaggeration=6.81, lr=88.05 for 250 iterations...
# Iteration   50, KL divergence 2.4902, 50 iterations in 1.0256 sec
# Iteration  100, KL divergence 2.4655, 50 iterations in 0.8986 sec
# Iteration  150, KL divergence 2.4646, 50 iterations in 0.7164 sec
# Iteration  200, KL divergence 2.4646, 50 iterations in 0.6944 sec
# Iteration  250, KL divergence 2.4646, 50 iterations in 0.7067 sec
#    --> Time elapsed: 4.04 seconds
# ===> Running optimization with exaggeration=6.81, lr=88.05 for 500 iterations...
# Iteration   50, KL divergence 2.4646, 50 iterations in 0.7020 sec
# Iteration  100, KL divergence 2.4646, 50 iterations in 0.6983 sec
# Iteration  150, KL divergence 2.4646, 50 iterations in 0.6996 sec
# Iteration  200, KL divergence 2.4646, 50 iterations in 1.0040 sec
# Iteration  250, KL divergence 2.4646, 50 iterations in 1.1012 sec
# Iteration  300, KL divergence 2.4646, 50 iterations in 1.3114 sec
# Iteration  350, KL divergence 2.4646, 50 iterations in 0.9079 sec
# Iteration  400, KL divergence 2.4646, 50 iterations in 0.7393 sec
# Iteration  450, KL divergence 2.4646, 50 iterations in 0.7368 sec
# Iteration  500, KL divergence 2.4646, 50 iterations in 0.7476 sec
#    --> Time elapsed: 8.65 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 8.18 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.37 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.19 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 4.3675, 50 iterations in 15.9860 sec
# Iteration  100, KL divergence 4.4669, 50 iterations in 15.2342 sec
# Iteration  150, KL divergence 4.4645, 50 iterations in 14.0888 sec
# Iteration  200, KL divergence 4.4645, 50 iterations in 14.1372 sec
# Iteration  250, KL divergence 4.4645, 50 iterations in 14.3020 sec
#    --> Time elapsed: 73.75 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 500 iterations...
# Iteration   50, KL divergence 1.9398, 50 iterations in 17.4194 sec
# Iteration  100, KL divergence 1.7855, 50 iterations in 21.6986 sec
# Iteration  150, KL divergence 1.7165, 50 iterations in 26.1978 sec
# Iteration  200, KL divergence 1.6767, 50 iterations in 24.8917 sec
# Iteration  250, KL divergence 1.6507, 50 iterations in 15.5786 sec
# Iteration  300, KL divergence 1.6322, 50 iterations in 13.5351 sec
# Iteration  350, KL divergence 1.6189, 50 iterations in 14.3869 sec
# Iteration  400, KL divergence 1.6081, 50 iterations in 13.1704 sec
# Iteration  450, KL divergence 1.5993, 50 iterations in 13.7010 sec
# Iteration  500, KL divergence 1.5926, 50 iterations in 13.1686 sec
#    --> Time elapsed: 173.75 seconds
# n = 6000, d = 784, b=0.15
# Computed h_n = 0.2712
# Using perplexity = 46.35 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 13.60
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=13.597071306791426, exaggeration=13.597071306791426,
#      n_jobs=-1, perplexity=46.34776723804791, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 139 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 9.41 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.56 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.19 seconds
# ===> Running optimization with exaggeration=13.60, lr=441.27 for 250 iterations...
# Iteration   50, KL divergence 4.2641, 50 iterations in 15.2297 sec
# Iteration  100, KL divergence 4.3319, 50 iterations in 14.7411 sec
# Iteration  150, KL divergence 4.3325, 50 iterations in 17.1374 sec
# Iteration  200, KL divergence 4.3324, 50 iterations in 17.4271 sec
# Iteration  250, KL divergence 4.3324, 50 iterations in 15.0398 sec
#    --> Time elapsed: 79.58 seconds
# ===> Running optimization with exaggeration=13.60, lr=441.27 for 500 iterations...
# Iteration   50, KL divergence 4.3324, 50 iterations in 14.7805 sec
# Iteration  100, KL divergence 4.3324, 50 iterations in 14.6753 sec
# Iteration  150, KL divergence 4.3323, 50 iterations in 15.4658 sec
# Iteration  200, KL divergence 4.3322, 50 iterations in 16.8760 sec
# Iteration  250, KL divergence 4.3321, 50 iterations in 20.1642 sec
# Iteration  300, KL divergence 4.3321, 50 iterations in 16.7040 sec
# Iteration  350, KL divergence 4.3321, 50 iterations in 18.5797 sec
# Iteration  400, KL divergence 4.3321, 50 iterations in 15.7344 sec
# Iteration  450, KL divergence 4.3322, 50 iterations in 16.7890 sec
# Iteration  500, KL divergence 4.3322, 50 iterations in 16.3521 sec
#    --> Time elapsed: 166.12 seconds

# %%
plot_scatterplots(percentages, embeddings)
plot_density_histograms(percentages, embeddings, bins=50)

# %%
# trying smaller exaggeration 
more_percentages=[0.001, 0.01, 0.1, 0.5]
embeddings = generate_mnist_embeddings(more_percentages, b=0.05)
# Out:
# Perplexity value 30 is too high. Using perplexity 19.67 instead
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 59 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.09 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.18 seconds
# ===> Running optimization with exaggeration=12.00, lr=5.00 for 250 iterations...
# Iteration   50, KL divergence -0.3210, 50 iterations in 0.1054 sec
# Iteration  100, KL divergence 0.9650, 50 iterations in 0.0288 sec
# Iteration  150, KL divergence 0.9650, 50 iterations in 0.0244 sec
# Iteration  200, KL divergence 0.9650, 50 iterations in 0.0228 sec
# Iteration  250, KL divergence 0.9650, 50 iterations in 0.0253 sec
#    --> Time elapsed: 0.21 seconds
# ===> Running optimization with exaggeration=1.00, lr=60.00 for 500 iterations...
# Iteration   50, KL divergence 0.3526, 50 iterations in 0.0755 sec
# Iteration  100, KL divergence 0.3136, 50 iterations in 0.0635 sec
# Iteration  150, KL divergence 0.3128, 50 iterations in 0.0669 sec
# Iteration  200, KL divergence 0.3125, 50 iterations in 0.1525 sec
# Iteration  250, KL divergence 0.3125, 50 iterations in 0.1761 sec
# Iteration  300, KL divergence 0.3127, 50 iterations in 0.1249 sec
# Iteration  350, KL divergence 0.3124, 50 iterations in 0.1919 sec
# Iteration  400, KL divergence 0.3127, 50 iterations in 0.0988 sec
# Perplexity value 36 is too high. Using perplexity 19.67 instead
# Iteration  450, KL divergence 0.3127, 50 iterations in 0.2541 sec
# Iteration  500, KL divergence 0.3127, 50 iterations in 0.1877 sec
#    --> Time elapsed: 1.40 seconds
# n = 60, d = 784, b=0.05
# Computed h_n = 0.8149
# Using perplexity = 36.82 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 1.51
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=1.5059658546149228, exaggeration=1.5059658546149228,
#      n_jobs=-1, perplexity=36.815340133610476, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 59 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.08 seconds
# ===> Running optimization with exaggeration=1.51, lr=39.84 for 250 iterations...
# Iteration   50, KL divergence 0.5561, 50 iterations in 0.1076 sec
# Iteration  100, KL divergence 0.5630, 50 iterations in 0.1454 sec
# Iteration  150, KL divergence 0.5633, 50 iterations in 0.1206 sec
# Iteration  200, KL divergence 0.5638, 50 iterations in 0.1749 sec
# Iteration  250, KL divergence 0.5639, 50 iterations in 0.1225 sec
#    --> Time elapsed: 0.67 seconds
# ===> Running optimization with exaggeration=1.51, lr=39.84 for 500 iterations...
# Iteration   50, KL divergence 0.5638, 50 iterations in 0.1462 sec
# Iteration  100, KL divergence 0.5639, 50 iterations in 0.1990 sec
# Iteration  150, KL divergence 0.5635, 50 iterations in 0.1922 sec
# Iteration  200, KL divergence 0.5638, 50 iterations in 0.3051 sec
# Iteration  250, KL divergence 0.5637, 50 iterations in 0.1301 sec
# Iteration  300, KL divergence 0.5637, 50 iterations in 0.4035 sec
# Iteration  350, KL divergence 0.5637, 50 iterations in 0.2474 sec
# Iteration  400, KL divergence 0.5636, 50 iterations in 0.1867 sec
# Iteration  450, KL divergence 0.5638, 50 iterations in 0.1093 sec
# Iteration  500, KL divergence 0.5638, 50 iterations in 0.0732 sec
#    --> Time elapsed: 2.01 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.06 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.10 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.15 seconds
# ===> Running optimization with exaggeration=12.00, lr=50.00 for 250 iterations...
# Iteration   50, KL divergence 2.1947, 50 iterations in 1.5512 sec
# Iteration  100, KL divergence 2.5074, 50 iterations in 0.8191 sec
# Iteration  150, KL divergence 2.4598, 50 iterations in 0.5074 sec
# Iteration  200, KL divergence 2.4808, 50 iterations in 0.4661 sec
# Iteration  250, KL divergence 2.4783, 50 iterations in 0.4686 sec
#    --> Time elapsed: 3.81 seconds
# ===> Running optimization with exaggeration=1.00, lr=600.00 for 500 iterations...
# Iteration   50, KL divergence 1.0105, 50 iterations in 1.0499 sec
# Iteration  100, KL divergence 0.9649, 50 iterations in 1.2632 sec
# Iteration  150, KL divergence 0.9448, 50 iterations in 1.0753 sec
# Iteration  200, KL divergence 0.9335, 50 iterations in 1.0548 sec
# Iteration  250, KL divergence 0.9249, 50 iterations in 1.1675 sec
# Iteration  300, KL divergence 0.9200, 50 iterations in 1.1949 sec
# Iteration  350, KL divergence 0.9168, 50 iterations in 1.0470 sec
# Iteration  400, KL divergence 0.9157, 50 iterations in 1.0512 sec
# Iteration  450, KL divergence 0.9147, 50 iterations in 0.9328 sec
# Iteration  500, KL divergence 0.9123, 50 iterations in 0.8906 sec
#    --> Time elapsed: 10.73 seconds
# n = 600, d = 784, b=0.05
# Computed h_n = 0.7263
# Using perplexity = 41.31 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 1.90
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=1.8958986836690466, exaggeration=1.8958986836690466,
#      n_jobs=-1, perplexity=41.30749103131467, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 123 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.05 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=1.90, lr=316.47 for 250 iterations...
# Iteration   50, KL divergence 1.4454, 50 iterations in 0.9970 sec
# Iteration  100, KL divergence 1.4336, 50 iterations in 1.4507 sec
# Iteration  150, KL divergence 1.4314, 50 iterations in 1.0033 sec
# Iteration  200, KL divergence 1.4312, 50 iterations in 0.8272 sec
# Iteration  250, KL divergence 1.4318, 50 iterations in 0.8561 sec
#    --> Time elapsed: 5.15 seconds
# ===> Running optimization with exaggeration=1.90, lr=316.47 for 500 iterations...
# Iteration   50, KL divergence 1.4318, 50 iterations in 0.8325 sec
# Iteration  100, KL divergence 1.4315, 50 iterations in 0.8359 sec
# Iteration  150, KL divergence 1.4312, 50 iterations in 0.8384 sec
# Iteration  200, KL divergence 1.4312, 50 iterations in 0.8496 sec
# Iteration  250, KL divergence 1.4312, 50 iterations in 0.8523 sec
# Iteration  300, KL divergence 1.4311, 50 iterations in 1.0828 sec
# Iteration  350, KL divergence 1.4314, 50 iterations in 1.8229 sec
# Iteration  400, KL divergence 1.4313, 50 iterations in 0.9784 sec
# Iteration  450, KL divergence 1.4312, 50 iterations in 0.9171 sec
# Iteration  500, KL divergence 1.4314, 50 iterations in 0.8588 sec
#    --> Time elapsed: 9.88 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 8.19 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.36 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.21 seconds
# ===> Running optimization with exaggeration=12.00, lr=500.00 for 250 iterations...
# Iteration   50, KL divergence 4.3675, 50 iterations in 15.1128 sec
# Iteration  100, KL divergence 4.4669, 50 iterations in 18.7362 sec
# Iteration  150, KL divergence 4.4645, 50 iterations in 21.1467 sec
# Iteration  200, KL divergence 4.4645, 50 iterations in 14.4202 sec
# Iteration  250, KL divergence 4.4645, 50 iterations in 14.4048 sec
#    --> Time elapsed: 83.82 seconds
# ===> Running optimization with exaggeration=1.00, lr=6000.00 for 500 iterations...
# Iteration   50, KL divergence 1.9398, 50 iterations in 13.3885 sec
# Iteration  100, KL divergence 1.7855, 50 iterations in 13.9538 sec
# Iteration  150, KL divergence 1.7165, 50 iterations in 13.1939 sec
# Iteration  200, KL divergence 1.6767, 50 iterations in 13.2033 sec
# Iteration  250, KL divergence 1.6507, 50 iterations in 13.1039 sec
# Iteration  300, KL divergence 1.6322, 50 iterations in 14.9547 sec
# Iteration  350, KL divergence 1.6189, 50 iterations in 15.9437 sec
# Iteration  400, KL divergence 1.6081, 50 iterations in 16.8490 sec
# Iteration  450, KL divergence 1.5993, 50 iterations in 18.0106 sec
# Iteration  500, KL divergence 1.5926, 50 iterations in 20.2089 sec
#    --> Time elapsed: 152.82 seconds
# n = 6000, d = 784, b=0.05
# Computed h_n = 0.6473
# Using perplexity = 46.35 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 2.39
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=2.3867950310580737, exaggeration=2.3867950310580737,
#      n_jobs=-1, perplexity=46.34776723804791, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 139 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 12.25 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.75 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.27 seconds
# ===> Running optimization with exaggeration=2.39, lr=2513.83 for 250 iterations...
# Iteration   50, KL divergence 2.4651, 50 iterations in 16.8108 sec
# Iteration  100, KL divergence 2.4388, 50 iterations in 14.7325 sec
# Iteration  150, KL divergence 2.4347, 50 iterations in 14.1394 sec
# Iteration  200, KL divergence 2.4286, 50 iterations in 13.8405 sec
# Iteration  250, KL divergence 2.4277, 50 iterations in 14.0453 sec
#    --> Time elapsed: 73.57 seconds
# ===> Running optimization with exaggeration=2.39, lr=2513.83 for 500 iterations...
# Iteration   50, KL divergence 2.4280, 50 iterations in 15.4904 sec
# Iteration  100, KL divergence 2.4279, 50 iterations in 14.7049 sec
# Iteration  150, KL divergence 2.4276, 50 iterations in 15.1413 sec
# Iteration  200, KL divergence 2.4262, 50 iterations in 20.2082 sec
# Iteration  250, KL divergence 2.4263, 50 iterations in 18.5627 sec
# Iteration  300, KL divergence 2.4269, 50 iterations in 17.3365 sec
# Iteration  350, KL divergence 2.4285, 50 iterations in 24.0685 sec
# Iteration  400, KL divergence 2.4290, 50 iterations in 18.0572 sec
# Iteration  450, KL divergence 2.4295, 50 iterations in 14.2112 sec
# Iteration  500, KL divergence 2.4299, 50 iterations in 14.0071 sec
#    --> Time elapsed: 171.79 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 49.91 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 2.46 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.74 seconds
# ===> Running optimization with exaggeration=12.00, lr=2500.00 for 250 iterations...
# Iteration   50, KL divergence 5.3949, 50 iterations in 3.8520 sec
# Iteration  100, KL divergence 5.3435, 50 iterations in 3.9646 sec
# Iteration  150, KL divergence 5.3352, 50 iterations in 3.9011 sec
# Iteration  200, KL divergence 5.3309, 50 iterations in 3.7793 sec
# Iteration  250, KL divergence 5.3291, 50 iterations in 3.8251 sec
#    --> Time elapsed: 19.32 seconds
# ===> Running optimization with exaggeration=1.00, lr=30000.00 for 500 iterations...
# Iteration   50, KL divergence 2.9584, 50 iterations in 3.9894 sec
# Iteration  100, KL divergence 2.7336, 50 iterations in 7.1262 sec
# Iteration  150, KL divergence 2.6217, 50 iterations in 9.6130 sec
# Iteration  200, KL divergence 2.5506, 50 iterations in 11.4695 sec
# Iteration  250, KL divergence 2.5002, 50 iterations in 15.0731 sec
# Iteration  300, KL divergence 2.4614, 50 iterations in 13.3786 sec
# Iteration  350, KL divergence 2.4309, 50 iterations in 15.2819 sec
# Iteration  400, KL divergence 2.4062, 50 iterations in 16.5752 sec
# Iteration  450, KL divergence 2.3853, 50 iterations in 20.0768 sec
# Iteration  500, KL divergence 2.3674, 50 iterations in 19.8638 sec
#    --> Time elapsed: 132.45 seconds
# n = 30000, d = 784, b=0.05
# Computed h_n = 0.5972
# Using perplexity = 50.23 (base κ = 30, exponent α = 0.05)
# Using early exaggeration = 2.80
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=2.80357465674917, exaggeration=2.80357465674917,
#      n_jobs=-1, perplexity=50.231635361336316, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 150 nearest neighbors using Annoy approximate search using euclidean distance...
#    --> Time elapsed: 55.83 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 3.11 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.76 seconds
# ===> Running optimization with exaggeration=2.80, lr=10700.62 for 250 iterations...
# Iteration   50, KL divergence 3.5769, 50 iterations in 4.8393 sec
# Iteration  100, KL divergence 3.4823, 50 iterations in 5.0748 sec
# Iteration  150, KL divergence 3.4225, 50 iterations in 4.8802 sec
# Iteration  200, KL divergence 3.3826, 50 iterations in 5.1023 sec
# Iteration  250, KL divergence 3.3665, 50 iterations in 4.9151 sec
#    --> Time elapsed: 24.81 seconds
# ===> Running optimization with exaggeration=2.80, lr=10700.62 for 500 iterations...
# Iteration   50, KL divergence 3.3594, 50 iterations in 4.9080 sec
# Iteration  100, KL divergence 3.3525, 50 iterations in 4.7926 sec
# Iteration  150, KL divergence 3.3454, 50 iterations in 5.1007 sec
# Iteration  200, KL divergence 3.3406, 50 iterations in 4.9203 sec
# Iteration  250, KL divergence 3.3342, 50 iterations in 6.0237 sec
# Iteration  300, KL divergence 3.3321, 50 iterations in 7.4043 sec
# Iteration  350, KL divergence 3.3302, 50 iterations in 6.9593 sec
# Iteration  400, KL divergence 3.3287, 50 iterations in 5.5558 sec
# Iteration  450, KL divergence 3.3277, 50 iterations in 5.0552 sec
# Iteration  500, KL divergence 3.3269, 50 iterations in 5.1526 sec
#    --> Time elapsed: 55.87 seconds

# %%
len(percentages)
# Out:
# 2

# %%
plot_scatterplots(more_percentages, embeddings)
plot_density_histograms(more_percentages, embeddings, bins=50)

# %%
## third attempt, try a slightly smaller perplexity base value (could help with very small data sets) and a ever so slightly larger b (more EE, could lead to less scaling and more concentration)

percentages3=[0.001, 0.01, 0.1, 0.5, 1.0]
embeddings3 = generate_mnist_embeddings(more_percentages, b=0.07, kappa=15)
# Out:
# Perplexity value 30 is too high. Using perplexity 19.67 instead
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 59 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.03 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=12.00, lr=5.00 for 250 iterations...
# Iteration   50, KL divergence -0.3210, 50 iterations in 0.1021 sec
# Iteration  100, KL divergence 0.9650, 50 iterations in 0.0180 sec
# Iteration  150, KL divergence 0.9650, 50 iterations in 0.0186 sec
# Iteration  200, KL divergence 0.9650, 50 iterations in 0.0320 sec
# Iteration  250, KL divergence 0.9650, 50 iterations in 0.0309 sec
#    --> Time elapsed: 0.20 seconds
# ===> Running optimization with exaggeration=1.00, lr=60.00 for 500 iterations...
# Iteration   50, KL divergence 0.3526, 50 iterations in 0.1094 sec
# Iteration  100, KL divergence 0.3136, 50 iterations in 0.0716 sec
# Iteration  150, KL divergence 0.3128, 50 iterations in 0.0748 sec
# Iteration  200, KL divergence 0.3125, 50 iterations in 0.0566 sec
# Iteration  250, KL divergence 0.3125, 50 iterations in 0.0537 sec
# Iteration  300, KL divergence 0.3127, 50 iterations in 0.0743 sec
# Iteration  350, KL divergence 0.3124, 50 iterations in 0.1358 sec
# Iteration  400, KL divergence 0.3127, 50 iterations in 0.1002 sec
# Iteration  450, KL divergence 0.3127, 50 iterations in 0.0824 sec
# Iteration  500, KL divergence 0.3127, 50 iterations in 0.1244 sec
#    --> Time elapsed: 0.88 seconds
# n = 60, d = 784, b=0.07
# Computed h_n = 0.7508
# Using perplexity = 18.41 (base κ = 15, exponent α = 0.05)
# Using early exaggeration = 1.77
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=1.7739491841850727, exaggeration=1.7739491841850727,
#      n_jobs=-1, perplexity=18.407670066805238, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 55 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.01 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.00 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.01 seconds
# ===> Running optimization with exaggeration=1.77, lr=33.82 for 250 iterations...
# Iteration   50, KL divergence 0.7163, 50 iterations in 0.1305 sec
# Iteration  100, KL divergence 0.7098, 50 iterations in 0.1761 sec
# Iteration  150, KL divergence 0.7098, 50 iterations in 0.0641 sec
# Iteration  200, KL divergence 0.7099, 50 iterations in 0.0584 sec
# Iteration  250, KL divergence 0.7100, 50 iterations in 0.0528 sec
#    --> Time elapsed: 0.48 seconds
# ===> Running optimization with exaggeration=1.77, lr=33.82 for 500 iterations...
# Iteration   50, KL divergence 0.7098, 50 iterations in 0.0668 sec
# Iteration  100, KL divergence 0.7098, 50 iterations in 0.0553 sec
# Iteration  150, KL divergence 0.7098, 50 iterations in 0.0541 sec
# Iteration  200, KL divergence 0.7099, 50 iterations in 0.0589 sec
# Iteration  250, KL divergence 0.7099, 50 iterations in 0.0654 sec
# Iteration  300, KL divergence 0.7099, 50 iterations in 0.0573 sec
# Iteration  350, KL divergence 0.7099, 50 iterations in 0.0551 sec
# Iteration  400, KL divergence 0.7098, 50 iterations in 0.0538 sec
# Iteration  450, KL divergence 0.7097, 50 iterations in 0.0686 sec
# Iteration  500, KL divergence 0.7099, 50 iterations in 0.0625 sec
#    --> Time elapsed: 0.60 seconds
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=12, n_jobs=-1, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 90 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.04 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.03 seconds
# ===> Running optimization with exaggeration=12.00, lr=50.00 for 250 iterations...
# Iteration   50, KL divergence 2.1947, 50 iterations in 1.0436 sec
# Iteration  100, KL divergence 2.5074, 50 iterations in 2.1167 sec
# Iteration  150, KL divergence 2.4598, 50 iterations in 3.5985 sec
# Iteration  200, KL divergence 2.4808, 50 iterations in 3.2639 sec
# Iteration  250, KL divergence 2.4783, 50 iterations in 2.7607 sec
#    --> Time elapsed: 12.94 seconds
# ===> Running optimization with exaggeration=1.00, lr=600.00 for 500 iterations...
# Iteration   50, KL divergence 1.0105, 50 iterations in 2.9865 sec
# Iteration  100, KL divergence 0.9649, 50 iterations in 2.6377 sec
# Iteration  150, KL divergence 0.9448, 50 iterations in 2.1582 sec
# Iteration  200, KL divergence 0.9335, 50 iterations in 1.8369 sec
# Iteration  250, KL divergence 0.9249, 50 iterations in 2.3783 sec
# Iteration  300, KL divergence 0.9200, 50 iterations in 1.5705 sec
# Iteration  350, KL divergence 0.9168, 50 iterations in 1.5774 sec
# Iteration  400, KL divergence 0.9157, 50 iterations in 1.5454 sec
# Iteration  450, KL divergence 0.9147, 50 iterations in 1.3528 sec
# Iteration  500, KL divergence 0.9123, 50 iterations in 2.0423 sec
#    --> Time elapsed: 20.09 seconds
# n = 600, d = 784, b=0.07
# Computed h_n = 0.6390
# Using perplexity = 20.65 (base κ = 15, exponent α = 0.05)
# Using early exaggeration = 2.45
# --------------------------------------------------------------------------------
# TSNE(early_exaggeration=2.4487315400541996, exaggeration=2.4487315400541996,
#      n_jobs=-1, perplexity=20.653745515657334, random_state=42, verbose=True)
# --------------------------------------------------------------------------------
# ===> Finding 61 nearest neighbors using exact search using euclidean distance...
#    --> Time elapsed: 0.18 seconds
# ===> Calculating affinity matrix...
#    --> Time elapsed: 0.05 seconds
# ===> Calculating PCA-based initialization...
#    --> Time elapsed: 0.06 seconds
# ===> Running optimization with exaggeration=2.45, lr=245.02 for 250 iterations...
# Iteration   50, KL divergence 1.7729, 50 iterations in 1.6958 sec
# Iteration  100, KL divergence 1.8581, 50 iterations in 2.2837 sec
# Iteration  150, KL divergence 1.8565, 50 iterations in 1.6631 sec
# Iteration  200, KL divergence 1.8561, 50 iterations in 1.6023 sec
# Iteration  250, KL divergence 1.8568, 50 iterations in 1.3784 sec
#    --> Time elapsed: 8.64 seconds
# ===> Running optimization with exaggeration=2.45, lr=245.02 for 500 iterations...
# Iteration   50, KL divergence 1.8567, 50 iterations in 1.3279 sec
# Iteration  100, KL divergence 1.8567, 50 iterations in 1.7151 sec
# Iteration  150, KL divergence 1.8570, 50 iterations in 0.9470 sec
# Iteration  200, KL divergence 1.8571, 50 iterations in 0.8672 sec
# Iteration  250, KL divergence 1.8569, 50 iterations in 1.0004 sec
# Iteration  300, KL divergence 1.8579, 50 iterations in 1.2997 sec

# %%
plot_scatterplots(percentages3, embeddings3)
plot_density_histograms(percentages3, embeddings3, bins=50)
